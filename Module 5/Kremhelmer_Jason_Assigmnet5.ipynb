# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.985074875, score: 23
# Scores: (min: 23, avg: 23, max: 23)
#
# Run: 2, exploration: 0.8911090557802088, score: 21
# Scores: (min: 21, avg: 22, max: 23)
#
# Run: 3, exploration: 0.8390886103705794, score: 13
# Scores: (min: 13, avg: 19, max: 23)
#
# Run: 4, exploration: 0.7628626641409962, score: 20
# Scores: (min: 13, avg: 19.25, max: 23)
#
# Run: 5, exploration: 0.7255664080186093, score: 11
# Scores: (min: 11, avg: 17.6, max: 23)
#
# Run: 6, exploration: 0.6866430931872001, score: 12
# Scores: (min: 11, avg: 16.666666666666668, max: 23)
#
# Run: 7, exploration: 0.653073201944699, score: 11
# Scores: (min: 11, avg: 15.857142857142858, max: 23)
#
# Run: 8, exploration: 0.6242658676435396, score: 10
# Scores: (min: 10, avg: 15.125, max: 23)
#
# Run: 9, exploration: 0.5997278763867329, score: 9
# Scores: (min: 9, avg: 14.444444444444445, max: 23)
#
# Run: 10, exploration: 0.5732736268885887, score: 10
# Scores: (min: 9, avg: 14, max: 23)
#
# Run: 11, exploration: 0.5452463540625918, score: 11
# Scores: (min: 9, avg: 13.727272727272727, max: 23)
#
# Run: 12, exploration: 0.5159963842937159, score: 12
# Scores: (min: 9, avg: 13.583333333333334, max: 23)
#
# Run: 13, exploration: 0.4932355662165453, score: 10
# Scores: (min: 9, avg: 13.307692307692308, max: 23)
#
# Run: 14, exploration: 0.457510005540005, score: 16
# Scores: (min: 9, avg: 13.5, max: 23)
#
# Run: 15, exploration: 0.43952667968844233, score: 9
# Scores: (min: 9, avg: 13.2, max: 23)
#
# Run: 16, exploration: 0.42013897252428334, score: 10
# Scores: (min: 9, avg: 13, max: 23)
#
# Run: 17, exploration: 0.3995984329713264, score: 11
# Scores: (min: 9, avg: 12.882352941176471, max: 23)
#
# Run: 18, exploration: 0.37816180712868996, score: 12
# Scores: (min: 9, avg: 12.833333333333334, max: 23)
#
# Run: 19, exploration: 0.3614809303671764, score: 10
# Scores: (min: 9, avg: 12.68421052631579, max: 23)
#
# Run: 20, exploration: 0.3438081748424137, score: 11
# Scores: (min: 9, avg: 12.6, max: 23)
#
# Run: 21, exploration: 0.33195389135223546, score: 8
# Scores: (min: 8, avg: 12.380952380952381, max: 23)
#
# Run: 22, exploration: 0.3125753549412418, score: 13
# Scores: (min: 8, avg: 12.409090909090908, max: 23)
#
# Run: 23, exploration: 0.30028896908517405, score: 9
# Scores: (min: 8, avg: 12.26086956521739, max: 23)
#
# Run: 24, exploration: 0.28704309604425327, score: 10
# Scores: (min: 8, avg: 12.166666666666666, max: 23)
#
# Run: 25, exploration: 0.2743815040481898, score: 10
# Scores: (min: 8, avg: 12.08, max: 23)
#
# Run: 26, exploration: 0.26359640222486147, score: 9
# Scores: (min: 8, avg: 11.961538461538462, max: 23)
#
# Run: 27, exploration: 0.2507092085103961, score: 11
# Scores: (min: 8, avg: 11.925925925925926, max: 23)
#
# Run: 28, exploration: 0.23725980767521673, score: 12
# Scores: (min: 8, avg: 11.928571428571429, max: 23)
#
# Run: 29, exploration: 0.22340924607110255, score: 13
# Scores: (min: 8, avg: 11.96551724137931, max: 23)
#
# Run: 30, exploration: 0.21248679717794605, score: 11
# Scores: (min: 8, avg: 11.933333333333334, max: 23)
#
# Run: 31, exploration: 0.2041345879004775, score: 9
# Scores: (min: 8, avg: 11.838709677419354, max: 23)
#
# Run: 32, exploration: 0.19513012515638165, score: 10
# Scores: (min: 8, avg: 11.78125, max: 23)
#
# Run: 33, exploration: 0.18746015382974018, score: 9
# Scores: (min: 8, avg: 11.696969696969697, max: 23)
#
# Run: 34, exploration: 0.17829525136613786, score: 11
# Scores: (min: 8, avg: 11.676470588235293, max: 23)
#
# Run: 35, exploration: 0.11527836319047392, score: 88
# Scores: (min: 8, avg: 13.857142857142858, max: 88)
#
# Run: 36, exploration: 0.0745342397963533, score: 88
# Scores: (min: 8, avg: 15.916666666666666, max: 88)
#
# Run: 37, exploration: 0.06285510723190912, score: 35
# Scores: (min: 8, avg: 16.43243243243243, max: 88)
#
# Run: 38, exploration: 0.040032972548509065, score: 91
# Scores: (min: 8, avg: 18.394736842105264, max: 91)
#
# Run: 39, exploration: 0.03325613897196732, score: 38
# Scores: (min: 8, avg: 18.897435897435898, max: 91)
#
# Run: 40, exploration: 0.025116802354115567, score: 57
# Scores: (min: 8, avg: 19.85, max: 91)
#
# Run: 41, exploration: 0.018686420266267767, score: 60
# Scores: (min: 8, avg: 20.829268292682926, max: 91)
#
# Run: 42, exploration: 0.013763663225419333, score: 62
# Scores: (min: 8, avg: 21.80952380952381, max: 91)
#
# Run: 43, exploration: 0.011263082556340478, score: 41
# Scores: (min: 8, avg: 22.25581395348837, max: 91)
#
# Run: 44, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 22.363636363636363, max: 91)
#
# Run: 45, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 22.377777777777776, max: 91)
#
# Run: 46, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 23.065217391304348, max: 91)
#
# Run: 47, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 24.29787234042553, max: 91)
#
# Run: 48, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 25.020833333333332, max: 91)
#
# Run: 49, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 25.591836734693878, max: 91)
#
# Run: 50, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 27.36, max: 114)
#
# Run: 51, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 28.392156862745097, max: 114)
#
# Run: 52, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 29.442307692307693, max: 114)
#
# Run: 53, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 30.50943396226415, max: 114)
#
# Run: 54, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 31.5, max: 114)
#
# Run: 55, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 33.58181818181818, max: 146)
#
# Run: 56, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 34.660714285714285, max: 146)
#
# Run: 57, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 35.36842105263158, max: 146)
#
# Run: 58, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 36.06896551724138, max: 146)
#
# Run: 59, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 38.152542372881356, max: 159)
#
# Run: 60, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 39.916666666666664, max: 159)
#
# Run: 61, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 41, max: 159)
#
# Run: 62, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 43.596774193548384, max: 202)
#
# Run: 63, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 45.84126984126984, max: 202)
#
# Run: 64, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 47, max: 202)
#
# Run: 65, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 48.69230769230769, max: 202)
#
# Run: 66, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 50.13636363636363, max: 202)
#
# Run: 67, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 51.40298507462686, max: 202)
#
# Run: 68, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 53.294117647058826, max: 202)
#
# Run: 69, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 53.85507246376812, max: 202)
#
# Run: 70, exploration: 0.01, score: 248
# Scores: (min: 8, avg: 56.628571428571426, max: 248)
#
# Run: 71, exploration: 0.01, score: 306
# Scores: (min: 8, avg: 60.140845070422536, max: 306)
#
# Run: 72, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 62.27777777777778, max: 306)
#
# Run: 73, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 63.342465753424655, max: 306)
#
# Run: 74, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 64.16216216216216, max: 306)
#
# Run: 75, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 65.16, max: 306)
#
# Run: 76, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 67.23684210526316, max: 306)
#
# Run: 77, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 69.0909090909091, max: 306)
#
# Run: 78, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 70.17948717948718, max: 306)
#
# Run: 79, exploration: 0.01, score: 309
# Scores: (min: 8, avg: 73.20253164556962, max: 309)
#
# Run: 80, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 73.575, max: 309)
#
# Run: 81, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 75.04938271604938, max: 309)
#
# Run: 82, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 76.8780487804878, max: 309)
#
# Run: 83, exploration: 0.01, score: 346
# Scores: (min: 8, avg: 80.12048192771084, max: 346)
#
# Run: 84, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 81.66666666666667, max: 346)
#
# Run: 85, exploration: 0.01, score: 229
# Scores: (min: 8, avg: 83.4, max: 346)
#
# Run: 86, exploration: 0.01, score: 258
# Scores: (min: 8, avg: 85.43023255813954, max: 346)
#
# Run: 87, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 87.36781609195403, max: 346)
#
# Run: 88, exploration: 0.01, score: 264
# Scores: (min: 8, avg: 89.375, max: 346)
#
# Run: 89, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 90.10112359550561, max: 346)
#
# Run: 90, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 91.45555555555555, max: 346)
#
# Run: 91, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 92.85714285714286, max: 346)
#
# Run: 92, exploration: 0.01, score: 260
# Scores: (min: 8, avg: 94.67391304347827, max: 346)
#
# Run: 93, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 95.73118279569893, max: 346)
#
# Run: 94, exploration: 0.01, score: 259
# Scores: (min: 8, avg: 97.46808510638297, max: 346)
#
# Run: 95, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 98.67368421052632, max: 346)
#
# Run: 96, exploration: 0.01, score: 252
# Scores: (min: 8, avg: 100.27083333333333, max: 346)
#
# Run: 97, exploration: 0.01, score: 386
# Scores: (min: 8, avg: 103.21649484536083, max: 386)
#
# Run: 98, exploration: 0.01, score: 262
# Scores: (min: 8, avg: 104.83673469387755, max: 386)
#
# Run: 99, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 106.1919191919192, max: 386)
#
# Run: 100, exploration: 0.01, score: 305
# Scores: (min: 8, avg: 108.18, max: 386)
#
# Run: 101, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 112.95, max: 500)
#
# Run: 102, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 114.98, max: 500)
#
# Run: 103, exploration: 0.01, score: 334
# Scores: (min: 8, avg: 118.19, max: 500)
#
# Run: 104, exploration: 0.01, score: 268
# Scores: (min: 8, avg: 120.67, max: 500)
#
# Run: 105, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 122.64, max: 500)
#
# Run: 106, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 124.91, max: 500)
#
# Run: 107, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 127.21, max: 500)
#
# Run: 108, exploration: 0.01, score: 288
# Scores: (min: 8, avg: 129.99, max: 500)
#
# Run: 109, exploration: 0.01, score: 390
# Scores: (min: 8, avg: 133.8, max: 500)
#
# Run: 110, exploration: 0.01, score: 250
# Scores: (min: 8, avg: 136.2, max: 500)
#
# Run: 111, exploration: 0.01, score: 259
# Scores: (min: 8, avg: 138.68, max: 500)
#
# Run: 112, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 140.91, max: 500)
#
# Run: 113, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 142.48, max: 500)
#
# Run: 114, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 144.22, max: 500)
#
# Run: 115, exploration: 0.01, score: 314
# Scores: (min: 8, avg: 147.27, max: 500)
#
# Run: 116, exploration: 0.01, score: 277
# Scores: (min: 8, avg: 149.94, max: 500)
#
# Run: 117, exploration: 0.01, score: 277
# Scores: (min: 8, avg: 152.6, max: 500)
#
# Run: 118, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 154.83, max: 500)
#
# Run: 119, exploration: 0.01, score: 315
# Scores: (min: 8, avg: 157.88, max: 500)
#
# Run: 120, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 159.82, max: 500)
#
# Run: 121, exploration: 0.01, score: 265
# Scores: (min: 9, avg: 162.39, max: 500)
#
# Run: 122, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 164.27, max: 500)
#
# Run: 123, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 166.25, max: 500)
#
# Run: 124, exploration: 0.01, score: 364
# Scores: (min: 9, avg: 169.79, max: 500)
#
# Run: 125, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 171.99, max: 500)
#
# Run: 126, exploration: 0.01, score: 290
# Scores: (min: 9, avg: 174.8, max: 500)
#
# Run: 127, exploration: 0.01, score: 424
# Scores: (min: 9, avg: 178.93, max: 500)
#
# Run: 128, exploration: 0.01, score: 197
# Scores: (min: 9, avg: 180.78, max: 500)
#
# Run: 129, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 183.01, max: 500)
#
# Run: 130, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 184.69, max: 500)
#
# Run: 131, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 186.9, max: 500)
#
# Run: 132, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 188.8, max: 500)
#
# Run: 133, exploration: 0.01, score: 183
# Scores: (min: 11, avg: 190.54, max: 500)
#
# Run: 134, exploration: 0.01, score: 203
# Scores: (min: 23, avg: 192.46, max: 500)
#
# Run: 135, exploration: 0.01, score: 287
# Scores: (min: 23, avg: 194.45, max: 500)
#
# Run: 136, exploration: 0.01, score: 204
# Scores: (min: 23, avg: 195.61, max: 500)
#
# Solved in 36 runs, 136 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-8-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.01  #Adjusted learning rate larger
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 18
# Scores: (min: 18, avg: 18, max: 18)
#
# Run: 2, exploration: 0.9091562615825302, score: 21
# Scores: (min: 18, avg: 19.5, max: 21)
#
# Run: 3, exploration: 0.8307187014821328, score: 19
# Scores: (min: 18, avg: 19.333333333333332, max: 21)
#
# Run: 4, exploration: 0.7292124703704616, score: 27
# Scores: (min: 18, avg: 21.25, max: 27)
#
# Run: 5, exploration: 0.6935613678313175, score: 11
# Scores: (min: 11, avg: 19.2, max: 27)
#
# Run: 6, exploration: 0.653073201944699, score: 13
# Scores: (min: 11, avg: 18.166666666666668, max: 27)
#
# Run: 7, exploration: 0.5878229785513479, score: 22
# Scores: (min: 11, avg: 18.714285714285715, max: 27)
#
# Run: 8, exploration: 0.5507399854171277, score: 14
# Scores: (min: 11, avg: 18.125, max: 27)
#
# Run: 9, exploration: 0.5185893309484582, score: 13
# Scores: (min: 11, avg: 17.555555555555557, max: 27)
#
# Run: 10, exploration: 0.4883155414435353, score: 13
# Scores: (min: 11, avg: 17.1, max: 27)
#
# Run: 11, exploration: 0.46444185833082485, score: 11
# Scores: (min: 11, avg: 16.545454545454547, max: 27)
#
# Run: 12, exploration: 0.43952667968844233, score: 12
# Scores: (min: 11, avg: 16.166666666666668, max: 27)
#
# Run: 13, exploration: 0.4222502236424958, score: 9
# Scores: (min: 9, avg: 15.615384615384615, max: 27)
#
# Run: 14, exploration: 0.39561243860243744, score: 14
# Scores: (min: 9, avg: 15.5, max: 27)
#
# Run: 15, exploration: 0.3632974174544486, score: 18
# Scores: (min: 9, avg: 15.666666666666666, max: 27)
#
# Run: 16, exploration: 0.3455358541129786, score: 11
# Scores: (min: 9, avg: 15.375, max: 27)
#
# Run: 17, exploration: 0.3302941218954743, score: 10
# Scores: (min: 9, avg: 15.058823529411764, max: 27)
#
# Run: 18, exploration: 0.3125753549412418, score: 12
# Scores: (min: 9, avg: 14.88888888888889, max: 27)
#
# Run: 19, exploration: 0.29580711868545667, score: 12
# Scores: (min: 9, avg: 14.736842105263158, max: 27)
#
# Run: 20, exploration: 0.28417984116121187, score: 9
# Scores: (min: 9, avg: 14.45, max: 27)
#
# Run: 21, exploration: 0.2730095965279488, score: 9
# Scores: (min: 9, avg: 14.19047619047619, max: 27)
#
# Run: 22, exploration: 0.2609670281126685, score: 10
# Scores: (min: 9, avg: 14, max: 27)
#
# Run: 23, exploration: 0.2494556624678441, score: 10
# Scores: (min: 9, avg: 13.826086956521738, max: 27)
#
# Run: 24, exploration: 0.23965031961336, score: 9
# Scores: (min: 9, avg: 13.625, max: 27)
#
# Run: 25, exploration: 0.22679417751985861, score: 12
# Scores: (min: 9, avg: 13.56, max: 27)
#
# Run: 26, exploration: 0.2167901907234072, score: 10
# Scores: (min: 9, avg: 13.423076923076923, max: 27)
#
# Run: 27, exploration: 0.20619134658263935, score: 11
# Scores: (min: 9, avg: 13.333333333333334, max: 27)
#
# Run: 28, exploration: 0.19709615934585656, score: 10
# Scores: (min: 9, avg: 13.214285714285714, max: 27)
#
# Run: 29, exploration: 0.18746015382974018, score: 11
# Scores: (min: 9, avg: 13.137931034482758, max: 27)
#
# Run: 30, exploration: 0.1800916657318127, score: 9
# Scores: (min: 9, avg: 13, max: 27)
#
# Run: 31, exploration: 0.1662122034722543, score: 17
# Scores: (min: 9, avg: 13.129032258064516, max: 27)
#
# Run: 32, exploration: 0.15650920157696743, score: 13
# Scores: (min: 9, avg: 13.125, max: 27)
#
# Run: 33, exploration: 0.13264825480308728, score: 34
# Scores: (min: 9, avg: 13.757575757575758, max: 34)
#
# Run: 34, exploration: 0.12365869841532712, score: 15
# Scores: (min: 9, avg: 13.794117647058824, max: 34)
#
# Run: 35, exploration: 0.11643985070121858, score: 13
# Scores: (min: 9, avg: 13.771428571428572, max: 34)
#
# Run: 36, exploration: 0.09339361644125409, score: 45
# Scores: (min: 9, avg: 14.63888888888889, max: 45)
#
# Run: 37, exploration: 0.089273984641318, score: 10
# Scores: (min: 9, avg: 14.513513513513514, max: 45)
#
# Run: 38, exploration: 0.08157186144027828, score: 19
# Scores: (min: 9, avg: 14.631578947368421, max: 45)
#
# Run: 39, exploration: 0.0712465030521374, score: 28
# Scores: (min: 9, avg: 14.974358974358974, max: 45)
#
# Run: 40, exploration: 0.06317096204211972, score: 25
# Scores: (min: 9, avg: 15.225, max: 45)
#
# Run: 41, exploration: 0.05462441922520914, score: 30
# Scores: (min: 9, avg: 15.585365853658537, max: 45)
#
# Run: 42, exploration: 0.05143559895690903, score: 13
# Scores: (min: 9, avg: 15.523809523809524, max: 45)
#
# Run: 43, exploration: 0.043375904776212296, score: 35
# Scores: (min: 9, avg: 15.976744186046512, max: 45)
#
# Run: 44, exploration: 0.03904210656169572, score: 22
# Scores: (min: 9, avg: 16.113636363636363, max: 45)
#
# Run: 45, exploration: 0.03514130927386981, score: 22
# Scores: (min: 9, avg: 16.244444444444444, max: 45)
#
# Run: 46, exploration: 0.032109488810599975, score: 19
# Scores: (min: 9, avg: 16.304347826086957, max: 45)
#
# Run: 47, exploration: 0.02832764101944931, score: 26
# Scores: (min: 9, avg: 16.51063829787234, max: 45)
#
# Run: 48, exploration: 0.024008889611965685, score: 34
# Scores: (min: 9, avg: 16.875, max: 45)
#
# Run: 49, exploration: 0.022269900979844076, score: 16
# Scores: (min: 9, avg: 16.857142857142858, max: 45)
#
# Run: 50, exploration: 0.020656869087560238, score: 16
# Scores: (min: 9, avg: 16.84, max: 45)
#
# Run: 51, exploration: 0.016903931611681827, score: 41
# Scores: (min: 9, avg: 17.313725490196077, max: 45)
#
# Run: 52, exploration: 0.015917127532080494, score: 13
# Scores: (min: 9, avg: 17.23076923076923, max: 45)
#
# Run: 53, exploration: 0.014987930304771725, score: 13
# Scores: (min: 9, avg: 17.150943396226417, max: 45)
#
# Run: 54, exploration: 0.014255172347583332, score: 11
# Scores: (min: 9, avg: 17.037037037037038, max: 45)
#
# Run: 55, exploration: 0.012895378303744804, score: 21
# Scores: (min: 9, avg: 17.10909090909091, max: 45)
#
# Run: 56, exploration: 0.01202146005600684, score: 15
# Scores: (min: 9, avg: 17.071428571428573, max: 45)
#
# Run: 57, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 17.57894736842105, max: 46)
#
# Run: 58, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 17.879310344827587, max: 46)
#
# Run: 59, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 18.050847457627118, max: 46)
#
# Run: 60, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 18.2, max: 46)
#
# Run: 61, exploration: 0.01, score: 54
# Scores: (min: 9, avg: 18.78688524590164, max: 54)
#
# Run: 62, exploration: 0.01, score: 56
# Scores: (min: 9, avg: 19.387096774193548, max: 56)
#
# Run: 63, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 19.571428571428573, max: 56)
#
# Run: 64, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 20.203125, max: 60)
#
# Run: 65, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 20.307692307692307, max: 60)
#
# Run: 66, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 21.075757575757574, max: 71)
#
# Run: 67, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 21.34328358208955, max: 71)
#
# Run: 68, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 21.16176470588235, max: 71)
#
# Run: 69, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 21.043478260869566, max: 71)
#
# Run: 70, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 21.285714285714285, max: 71)
#
# Run: 71, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 21.12676056338028, max: 71)
#
# Run: 72, exploration: 0.01, score: 102
# Scores: (min: 9, avg: 22.25, max: 102)
#
# Run: 73, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 22.73972602739726, max: 102)
#
# Run: 74, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 23.08108108108108, max: 102)
#
# Run: 75, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 23.30666666666667, max: 102)
#
# Run: 76, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 23.223684210526315, max: 102)
#
# Run: 77, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 23.025974025974026, max: 102)
#
# Run: 78, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.858974358974358, max: 102)
#
# Run: 79, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 23.924050632911392, max: 107)
#
# Run: 80, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 24.25, max: 107)
#
# Run: 81, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 24.62962962962963, max: 107)
#
# Run: 82, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 25.01219512195122, max: 107)
#
# Run: 83, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 26.349397590361445, max: 136)
#
# Run: 84, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 26.916666666666668, max: 136)
#
# Run: 85, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 26.96470588235294, max: 136)
#
# Run: 86, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 27.38372093023256, max: 136)
#
# Run: 87, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 27.79310344827586, max: 136)
#
# Run: 88, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 28.011363636363637, max: 136)
#
# Run: 89, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.808988764044944, max: 136)
#
# Run: 90, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 27.666666666666668, max: 136)
#
# Run: 91, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 27.626373626373628, max: 136)
#
# Run: 92, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 27.57608695652174, max: 136)
#
# Run: 93, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 27.763440860215052, max: 136)
#
# Run: 94, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 27.872340425531913, max: 136)
#
# Run: 95, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 27.810526315789474, max: 136)
#
# Run: 96, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 27.677083333333332, max: 136)
#
# Run: 97, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 27.556701030927837, max: 136)
#
# Run: 98, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 27.418367346938776, max: 136)
#
# Run: 99, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 27.282828282828284, max: 136)
#
# Run: 100, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 27.15, max: 136)
#
# Run: 101, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 27.13, max: 136)
#
# Run: 102, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 27.18, max: 136)
#
# Run: 103, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 27.21, max: 136)
#
# Run: 104, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 27.12, max: 136)
#
# Run: 105, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 27.17, max: 136)
#
# Run: 106, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 27.44, max: 136)
#
# Run: 107, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 28.12, max: 136)
#
# Run: 108, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 29.33, max: 136)
#
# Run: 109, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 30.11, max: 136)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.08, max: 136)
#
# Run: 111, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.06, max: 136)
#
# Run: 112, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.04, max: 136)
#
# Run: 113, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 30.07, max: 136)
#
# Run: 114, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 31.77, max: 184)
#
# Run: 115, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 32.32, max: 184)
#
# Run: 116, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.31, max: 184)
#
# Run: 117, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 33.63, max: 184)
#
# Run: 118, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 34.78, max: 184)
#
# Run: 119, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 35.01, max: 184)
#
# Run: 120, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.02, max: 184)
#
# Run: 121, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.03, max: 184)
#
# Run: 122, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 35.06, max: 184)
#
# Run: 123, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 36.02, max: 184)
#
# Run: 124, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 36.52, max: 184)
#
# Run: 125, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 37.13, max: 184)
#
# Run: 126, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 38.77, max: 184)
#
# Run: 127, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 40.76, max: 210)
#
# Run: 128, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 41.78, max: 210)
#
# Run: 129, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 43.49, max: 210)
#
# Run: 130, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 44.86, max: 210)
#
# Run: 131, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 46.05, max: 210)
#
# Run: 132, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 46.32, max: 210)
#
# Run: 133, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 46.07, max: 210)
#
# Run: 134, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 46.01, max: 210)
#
# Run: 135, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.97, max: 210)
#
# Run: 136, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.62, max: 210)
#
# Run: 137, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.61, max: 210)
#
# Run: 138, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 45.5, max: 210)
#
# Run: 139, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.32, max: 210)
#
# Run: 140, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.16, max: 210)
#
# Run: 141, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 44.96, max: 210)
#
# Run: 142, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 44.91, max: 210)
#
# Run: 143, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 44.67, max: 210)
#
# Run: 144, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 44.54, max: 210)
#
# Run: 145, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 44.43, max: 210)
#
# Run: 146, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 44.32, max: 210)
#
# Run: 147, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 44.14, max: 210)
#
# Run: 148, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 43.91, max: 210)
#
# Run: 149, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.85, max: 210)
#
# Run: 150, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 43.77, max: 210)
#
# Run: 151, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 43.45, max: 210)
#
# Run: 152, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 43.4, max: 210)
#
# Run: 153, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.37, max: 210)
#
# Run: 154, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 43.39, max: 210)
#
# Run: 155, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 43.26, max: 210)
#
# Run: 156, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 43.23, max: 210)
#
# Run: 157, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 42.85, max: 210)
#
# Run: 158, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42.59, max: 210)
#
# Run: 159, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 42.72, max: 210)
#
# Run: 160, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.55, max: 210)
#
# Run: 161, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.11, max: 210)
#
# Run: 162, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.65, max: 210)
#
# Run: 163, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.44, max: 210)
#
# Run: 164, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 40.95, max: 210)
#
# Run: 165, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 40.89, max: 210)
#
# Run: 166, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 40.35, max: 210)
#
# Run: 167, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 40.48, max: 210)
#
# Run: 168, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 40.64, max: 210)
#
# Run: 169, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 41.15, max: 210)
#
# Run: 170, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 41.07, max: 210)
#
# Run: 171, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 41.19, max: 210)
#
# Run: 172, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 40.46, max: 210)
#
# Run: 173, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 40.13, max: 210)
#
# Run: 174, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 39.95, max: 210)
#
# Run: 175, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 40, max: 210)
#
# Run: 176, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 40.51, max: 210)
#
# Run: 177, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 41.25, max: 210)
#
# Run: 178, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 41.29, max: 210)
#
# Run: 179, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 40.55, max: 210)
#
# Run: 180, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 40.18, max: 210)
#
# Run: 181, exploration: 0.01, score: 260
# Scores: (min: 8, avg: 42.23, max: 260)
#
# Run: 182, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 42.44, max: 260)
#
# Run: 183, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 41.2, max: 260)
#
# Run: 184, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.55, max: 260)
#
# Run: 185, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 40.35, max: 260)
#
# Run: 186, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 40.79, max: 260)
#
# Run: 187, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 41.77, max: 260)
#
# Run: 188, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 41.74, max: 260)
#
# Run: 189, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 42.87, max: 260)
#
# Run: 190, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 44.7, max: 260)
#
# Run: 191, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 44.99, max: 260)
#
# Run: 192, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 45.25, max: 260)
#
# Run: 193, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 45.6, max: 260)
#
# Run: 194, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 45.51, max: 260)
#
# Run: 195, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 45.53, max: 260)
#
# Run: 196, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 46.73, max: 260)
#
# Run: 197, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 48.13, max: 260)
#
# Run: 198, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 49.22, max: 260)
#
# Run: 199, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 49.47, max: 260)
#
# Run: 200, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 49.51, max: 260)
#
# Run: 201, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 49.61, max: 260)
#
# Run: 202, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 49.65, max: 260)
#
# Run: 203, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 49.52, max: 260)
#
# Run: 204, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 49.53, max: 260)
#
# Run: 205, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 49.67, max: 260)
#
# Run: 206, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 49.4, max: 260)
#
# Run: 207, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 48.64, max: 260)
#
# Run: 208, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 47.4, max: 260)
#
# Run: 209, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 46.6, max: 260)
#
# Run: 210, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 46.6, max: 260)
#
# Run: 211, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 46.61, max: 260)
#
# Run: 212, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 46.6, max: 260)
#
# Run: 213, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 46.57, max: 260)
#
# Run: 214, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 44.84, max: 260)
#
# Run: 215, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 44.21, max: 260)
#
# Run: 216, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 44.21, max: 260)
#
# Run: 217, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 42.9, max: 260)
#
# Run: 218, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 41.78, max: 260)
#
# Run: 219, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 41.54, max: 260)
#
# Run: 220, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 42.3, max: 260)
#
# Run: 221, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 42.36, max: 260)
#
# Run: 222, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 42.39, max: 260)
#
# Run: 223, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 41.75, max: 260)
#
# Run: 224, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 41.68, max: 260)
#
# Run: 225, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 41.58, max: 260)
#
# Run: 226, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 40.34, max: 260)
#
# Run: 227, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 38.99, max: 260)
#
# Run: 228, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 39.11, max: 260)
#
# Run: 229, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 37.92, max: 260)
#
# Run: 230, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 36.7, max: 260)
#
# Run: 231, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 35.65, max: 260)
#
# Run: 232, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.35, max: 260)
#
# Run: 233, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.36, max: 260)
#
# Run: 234, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.37, max: 260)
#
# Run: 235, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 35.42, max: 260)
#
# Run: 236, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.42, max: 260)
#
# Run: 237, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 36.34, max: 260)
#
# Run: 238, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 37.35, max: 260)
#
# Run: 239, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 37.37, max: 260)
#
# Run: 240, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 37.38, max: 260)
#
# Run: 241, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 37.43, max: 260)
#
# Run: 242, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 37.56, max: 260)
#
# Run: 243, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 37.59, max: 260)
#
# Run: 244, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 37.6, max: 260)
#
# Run: 245, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 37.59, max: 260)
#
# Run: 246, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 37.63, max: 260)
#
# Run: 247, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 37.83, max: 260)
#
# Run: 248, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 37.86, max: 260)
#
# Run: 249, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 38.79, max: 260)
#
# Run: 250, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 38.82, max: 260)
#
# Run: 251, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 39.17, max: 260)
#
# Run: 252, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39.18, max: 260)
#
# Run: 253, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 39.19, max: 260)
#
# Run: 254, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 39.4, max: 260)
#
# Run: 255, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 40.25, max: 260)
#
# Run: 256, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 40.69, max: 260)
#
# Run: 257, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 40.88, max: 260)
#
# Run: 258, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 40.9, max: 260)
#
# Run: 259, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 40.58, max: 260)
#
# Run: 260, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 40.56, max: 260)
#
# Run: 261, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.55, max: 260)
#
# Run: 262, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 40.57, max: 260)
#
# Run: 263, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 40.77, max: 260)
#
# Run: 264, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 41.38, max: 260)
#
# Run: 265, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 41.49, max: 260)
#
# Run: 266, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 41.73, max: 260)
#
# Run: 267, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 41.34, max: 260)
#
# Run: 268, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 41.63, max: 260)
#
# Run: 269, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 42.02, max: 260)
#
# Run: 270, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 42.07, max: 260)
#
# Run: 271, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 42.26, max: 260)
#
# Run: 272, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 42.29, max: 260)
#
# Run: 273, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 42.26, max: 260)
#
# Run: 274, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 43.46, max: 260)
#
# Run: 275, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 43.86, max: 260)
#
# Run: 276, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 44.32, max: 260)
#
# Run: 277, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 43.94, max: 260)
#
# Run: 278, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.9, max: 260)
#
# Run: 279, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.67, max: 260)
#
# Run: 280, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 43.63, max: 260)
#
# Run: 281, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 41.12, max: 198)
#
# Run: 282, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.45, max: 198)
#
# Run: 283, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.42, max: 198)
#
# Run: 284, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.42, max: 198)
#
# Run: 285, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.4, max: 198)
#
# Run: 286, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.43, max: 198)
#
# Run: 287, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 37.91, max: 198)
#
# Run: 288, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 37.56, max: 198)
#
# Run: 289, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.42, max: 198)
#
# Run: 290, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.54, max: 156)
#
# Run: 291, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.1, max: 156)
#
# Run: 292, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.7, max: 156)
#
# Run: 293, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33, max: 156)
#
# Run: 294, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.8, max: 156)
#
# Run: 295, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.65, max: 156)
#
# Run: 296, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.4, max: 156)
#
# Run: 297, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.94, max: 150)
#
# Run: 298, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.8, max: 150)
#
# Run: 299, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.51, max: 150)
#
# Run: 300, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.43, max: 150)
#
# Run: 301, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.26, max: 150)
#
# Run: 302, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.05, max: 150)
#
# Run: 303, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.05, max: 150)
#
# Run: 304, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.96, max: 150)
#
# Run: 305, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.74, max: 150)
#
# Run: 306, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.71, max: 150)
#
# Run: 307, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.66, max: 150)
#
# Run: 308, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.65, max: 150)
#
# Run: 309, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.63, max: 150)
#
# Run: 310, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.63, max: 150)
#
# Run: 311, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.62, max: 150)
#
# Run: 312, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.61, max: 150)
#
# Run: 313, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.61, max: 150)
#
# Run: 314, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.6, max: 150)
#
# Run: 315, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.6, max: 150)
#
# Run: 316, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.59, max: 150)
#
# Run: 317, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.57, max: 150)
#
# Run: 318, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.51, max: 150)
#
# Run: 319, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.5, max: 150)
#
# Run: 320, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.74, max: 150)
#
# Run: 321, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 26.69, max: 150)
#
# Run: 322, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.62, max: 150)
#
# Run: 323, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 26.28, max: 150)
#
# Run: 324, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 25.87, max: 150)
#
# Run: 325, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.34, max: 150)
#
# Run: 326, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.93, max: 150)
#
# Run: 327, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.28, max: 150)
#
# Run: 328, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.14, max: 150)
#
# Run: 329, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 22.63, max: 150)
#
# Run: 330, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 22.52, max: 150)
#
# Run: 331, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 22.37, max: 150)
#
# Run: 332, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 22.45, max: 150)
#
# Run: 333, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 22.53, max: 150)
#
# Run: 334, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 22.59, max: 150)
#
# Run: 335, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 22.63, max: 150)
#
# Run: 336, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 22.72, max: 150)
#
# Run: 337, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 21.95, max: 150)
#
# Run: 338, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 21.02, max: 150)
#
# Run: 339, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 21.16, max: 150)
#
# Run: 340, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 21.23, max: 150)
#
# Run: 341, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 21.24, max: 150)
#
# Run: 342, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 21.24, max: 150)
#
# Run: 343, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 21.3, max: 150)
#
# Run: 344, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 21.4, max: 150)
#
# Run: 345, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 21.51, max: 150)
#
# Run: 346, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 21.61, max: 150)
#
# Run: 347, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 21.66, max: 150)
#
# Run: 348, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 21.75, max: 150)
#
# Run: 349, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 20.93, max: 150)
#
# Run: 350, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 21.05, max: 150)
#
# Run: 351, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 20.86, max: 150)
#
# Run: 352, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 21, max: 150)
#
# Run: 353, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 21.08, max: 150)
#
# Run: 354, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 21.1, max: 150)
#
# Run: 355, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 20.46, max: 150)
#
# Run: 356, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20, max: 150)
#
# Run: 357, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.82, max: 150)
#
# Run: 358, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.83, max: 150)
#
# Run: 359, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.84, max: 150)
#
# Run: 360, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.85, max: 150)
#
# Run: 361, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.86, max: 150)
#
# Run: 362, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.83, max: 150)
#
# Run: 363, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.62, max: 150)
#
# Run: 364, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19, max: 150)
#
# Run: 365, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.76, max: 150)
#
# Run: 366, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.45, max: 150)
#
# Run: 367, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.41, max: 150)
#
# Run: 368, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 17.95, max: 150)
#
# Run: 369, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.02, max: 150)
#
# Run: 370, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.77, max: 150)
#
# Run: 371, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.45, max: 150)
#
# Run: 372, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.22, max: 150)
#
# Run: 373, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.08, max: 150)
#
# Run: 374, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.68, max: 114)
#
# Run: 375, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.93, max: 114)
#
# Run: 376, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.88, max: 44)
#
# Run: 377, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.54, max: 36)
#
# Run: 378, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.54, max: 36)
#
# Run: 379, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.53, max: 36)
#
# Run: 380, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.54, max: 36)
#
# Run: 381, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.53, max: 36)
#
# Run: 382, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.52, max: 36)
#
# Run: 383, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.51, max: 36)
#
# Run: 384, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.52, max: 36)
#
# Run: 385, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.52, max: 36)
#
# Run: 386, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.5, max: 36)
#
# Run: 387, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.49, max: 36)
#
# Run: 388, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.49, max: 36)
#
# Run: 389, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.49, max: 36)
#
# Run: 390, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.48, max: 36)
#
# Run: 391, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.5, max: 36)
#
# Run: 392, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.5, max: 36)
#
# Run: 393, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.48, max: 36)
#
# Run: 394, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.48, max: 36)
#
# Run: 395, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.49, max: 36)
#
# Run: 396, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.49, max: 36)
#
# Run: 397, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.49, max: 36)
#
# Run: 398, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.5, max: 36)
#
# Run: 399, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.5, max: 36)
#
# Run: 400, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.5, max: 36)
#
# Run: 401, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.49, max: 36)
#
# Run: 402, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.5, max: 36)
#
# Run: 403, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.51, max: 36)
#
# Run: 404, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.51, max: 36)
#
# Run: 405, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.53, max: 36)
#
# Run: 406, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.53, max: 36)
#
# Run: 407, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.53, max: 36)
#
# Run: 408, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.52, max: 36)
#
# Run: 409, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.53, max: 36)
#
# Run: 410, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.53, max: 36)
#
# Run: 411, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.54, max: 36)
#
# Run: 412, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.55, max: 36)
#
# Run: 413, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.56, max: 36)
#
# Run: 414, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.56, max: 36)
#
# Run: 415, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.56, max: 36)
#
# Run: 416, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.57, max: 36)
#
# Run: 417, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.58, max: 36)
#
# Run: 418, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.59, max: 36)
#
# Run: 419, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.58, max: 36)
#
# Run: 420, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.57, max: 36)
#
# Run: 421, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.56, max: 36)
#
# Run: 422, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.57, max: 36)
#
# Run: 423, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.58, max: 36)
#
# Run: 424, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.56, max: 36)
#
# Run: 425, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.55, max: 36)
#
# Run: 426, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.56, max: 36)
#
# Run: 427, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.56, max: 36)
#
# Run: 428, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.56, max: 36)
#
# Run: 429, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.53, max: 36)
#
# Run: 430, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.5, max: 36)
#
# Run: 431, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.44, max: 36)
#
# Run: 432, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.39, max: 36)
#
# Run: 433, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 12.65, max: 44)
#
# Run: 434, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.64, max: 44)
#
# Run: 435, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.68, max: 44)
#
# Run: 436, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 12.9, max: 44)
#
# Run: 437, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 13.13, max: 47)
#
# Run: 438, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 13.42, max: 47)
#
# Run: 439, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 13.35, max: 47)
#
# Run: 440, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 13.57, max: 47)
#
# Run: 441, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 13.72, max: 47)
#
# Run: 442, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 14.13, max: 62)
#
# Run: 443, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 14.81, max: 88)
#
# Run: 444, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.81, max: 88)
#
# Run: 445, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.74, max: 88)
#
# Run: 446, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.62, max: 88)
#
# Run: 447, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.44, max: 88)
#
# Run: 448, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.31, max: 88)
#
# Run: 449, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.2, max: 88)
#
# Run: 450, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.06, max: 88)
#
# Run: 451, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.9, max: 88)
#
# Run: 452, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.76, max: 88)
#
# Run: 453, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.66, max: 88)
#
# Run: 454, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.4, max: 88)
#
# Run: 455, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.19, max: 88)
#
# Run: 456, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.17, max: 88)
#
# Run: 457, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.19, max: 88)
#
# Run: 458, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.16, max: 88)
#
# Run: 459, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 13.33, max: 88)
#
# Run: 460, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.35, max: 88)
#
# Run: 461, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.35, max: 88)
#
# Run: 462, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.35, max: 88)
#
# Run: 463, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.34, max: 88)
#
# Run: 464, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.33, max: 88)
#
# Run: 465, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 13.46, max: 88)
#
# Run: 466, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.46, max: 88)
#
# Run: 467, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 13.56, max: 88)
#
# Run: 468, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.58, max: 88)
#
# Run: 469, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.57, max: 88)
#
# Run: 470, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.62, max: 88)
#
# Run: 471, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.65, max: 88)
#
# Run: 472, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 13.74, max: 88)
#
# Run: 473, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 13.84, max: 88)
#
# Run: 474, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.83, max: 88)
#
# Run: 475, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.9, max: 88)
#
# Run: 476, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.93, max: 88)
#
# Run: 477, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 14.08, max: 88)
#
# Run: 478, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.08, max: 88)
#
# Run: 479, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.1, max: 88)
#
# Run: 480, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.09, max: 88)
#
# Run: 481, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.11, max: 88)
#
# Run: 482, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 14.35, max: 88)
#
# Run: 483, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 14.95, max: 88)
#
# Run: 484, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 15.19, max: 88)
#
# Run: 485, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.19, max: 88)
#
# Run: 486, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.21, max: 88)
#
# Run: 487, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 15.34, max: 88)
#
# Run: 488, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 15.46, max: 88)
#
# Run: 489, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.46, max: 88)
#
# Run: 490, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.51, max: 88)
#
# Run: 491, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.49, max: 88)
#
# Run: 492, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.5, max: 88)
#
# Run: 493, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.52, max: 88)
#
# Run: 494, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.58, max: 88)
#
# Run: 495, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.57, max: 88)
#
# Run: 496, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.57, max: 88)
#
# Run: 497, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.57, max: 88)
#
# Run: 498, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 15.65, max: 88)
#
# Run: 499, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.64, max: 88)
#
# Run: 500, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 15.75, max: 88)
#
# Run: 501, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.77, max: 88)
#
# Run: 502, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.78, max: 88)
#
# Run: 503, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.79, max: 88)
#
# Run: 504, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.89, max: 88)
#
# Run: 505, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.89, max: 88)
#
# Run: 506, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.92, max: 88)
#
# Run: 507, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 16.19, max: 88)
#
# Run: 508, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.2, max: 88)
#
# Run: 509, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.27, max: 88)
#
# Run: 510, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.26, max: 88)
#
# Run: 511, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.27, max: 88)
#
# Run: 512, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.28, max: 88)
#
# Run: 513, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.38, max: 88)
#
# Run: 514, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.38, max: 88)
#
# Run: 515, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.37, max: 88)
#
# Run: 516, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.37, max: 88)
#
# Run: 517, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.36, max: 88)
#
# Run: 518, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.36, max: 88)
#
# Run: 519, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.36, max: 88)
#
# Run: 520, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.37, max: 88)
#
# Run: 521, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.42, max: 88)
#
# Run: 522, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.41, max: 88)
#
# Run: 523, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.45, max: 88)
#
# Run: 524, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.54, max: 88)
#
# Run: 525, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.54, max: 88)
#
# Run: 526, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.55, max: 88)
#
# Run: 527, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.56, max: 88)
#
# Run: 528, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.55, max: 88)
#
# Run: 529, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.55, max: 88)
#
# Run: 530, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.56, max: 88)
#
# Run: 531, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.56, max: 88)
#
# Run: 532, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.53, max: 88)
#
# Run: 533, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.18, max: 88)
#
# Run: 534, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.13, max: 88)
#
# Run: 535, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.05, max: 88)
#
# Run: 536, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.73, max: 88)
#
# Run: 537, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.35, max: 88)
#
# Run: 538, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.01, max: 88)
#
# Run: 539, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.92, max: 88)
#
# Run: 540, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.62, max: 88)
#
# Run: 541, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.41, max: 88)
#
# Run: 542, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.88, max: 88)
#
# Run: 543, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.09, max: 68)
#
# Run: 544, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.99, max: 68)
#
# Run: 545, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.95, max: 68)
#
# Run: 546, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.93, max: 68)
#
# Run: 547, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.87, max: 68)
#
# Run: 548, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.86, max: 68)
#
# Run: 549, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.85, max: 68)
#
# Run: 550, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.85, max: 68)
#
# Run: 551, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.86, max: 68)
#
# Run: 552, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.88, max: 68)
#
# Run: 553, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.89, max: 68)
#
# Run: 554, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.89, max: 68)
#
# Run: 555, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 13.14, max: 68)
#
# Run: 556, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.14, max: 68)
#
# Run: 557, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.12, max: 68)
#
# Run: 558, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.12, max: 68)
#
# Run: 559, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.99, max: 68)
#
# Run: 560, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.99, max: 68)
#
# Run: 561, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13, max: 68)
#
# Run: 562, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.01, max: 68)
#
# Run: 563, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.03, max: 68)
#
# Run: 564, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.02, max: 68)
#
# Run: 565, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.92, max: 68)
#
# Run: 566, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.93, max: 68)
#
# Run: 567, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.86, max: 68)
#
# Run: 568, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.87, max: 68)
#
# Run: 569, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.89, max: 68)
#
# Run: 570, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 12.99, max: 68)
#
# Run: 571, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 13.1, max: 68)
#
# Run: 572, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.16, max: 68)
#
# Run: 573, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.08, max: 68)
#
# Run: 574, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 13.22, max: 68)
#
# Run: 575, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 13.28, max: 68)
#
# Run: 576, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.25, max: 68)
#
# Run: 577, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.09, max: 68)
#
# Run: 578, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.09, max: 68)
#
# Run: 579, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.07, max: 68)
#
# Run: 580, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.06, max: 68)
#
# Run: 581, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 13.29, max: 68)
#
# Run: 582, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 13.15, max: 68)
#
# Run: 583, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.61, max: 36)
#
# Run: 584, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 12.52, max: 36)
#
# Run: 585, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.54, max: 36)
#
# Run: 586, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.55, max: 36)
#
# Run: 587, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.44, max: 36)
#
# Run: 588, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.32, max: 36)
#
# Run: 589, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.35, max: 36)
#
# Run: 590, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.3, max: 36)
#
# Run: 591, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.42, max: 36)
#
# Run: 592, exploration: 0.01, score: 62
# ...
# Run: 1247, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 32.04, max: 104)
#
# Run: 1248, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 31.98, max: 104)
#
# Run: 1249, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 31.85, max: 104)
#
# Run: 1250, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 31.69, max: 104)
#
# Run: 1251, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 31.61, max: 104)
#
# Run: 1252, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 31.18, max: 104)
#
# Run: 1253, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 31.18, max: 104)
#
# Run: 1254, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 31.34, max: 104)
#
# Run: 1255, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 31.47, max: 104)
#
# Run: 1256, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 31.58, max: 104)
#
# Run: 1257, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 31.54, max: 104)
#
# Run: 1258, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 31.47, max: 104)
#
# Run: 1259, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 31.64, max: 104)
#
# Run: 1260, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 31.63, max: 104)
#
# Run: 1261, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 31.27, max: 104)
#
# Run: 1262, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 31.17, max: 104)
#
# Run: 1263, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 31.06, max: 104)
#
# Run: 1264, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 30.98, max: 104)
#
# Run: 1265, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 30.09, max: 104)
#
# Run: 1266, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 30.03, max: 104)
#
# Run: 1267, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 29.94, max: 104)
#
# Run: 1268, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 30.26, max: 104)
#
# Run: 1269, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 30.33, max: 104)
#
# Run: 1270, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 30.54, max: 104)
#
# Run: 1271, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 30.63, max: 104)
#
# Run: 1272, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 30.76, max: 104)
#
# Run: 1273, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 30.99, max: 104)
#
# Run: 1274, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 30.38, max: 104)
#
# Run: 1275, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 30.4, max: 104)
#
# Run: 1276, exploration: 0.01, score: 66
# Scores: (min: 9, avg: 30.58, max: 104)
#
# Run: 1277, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 30.75, max: 104)
#
# Run: 1278, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 30.76, max: 104)
#
# Run: 1279, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 30.83, max: 104)
#
# Run: 1280, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 30.77, max: 104)
#
# Run: 1281, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 30.8, max: 104)
#
# Run: 1282, exploration: 0.01, score: 54
# Scores: (min: 9, avg: 30.98, max: 104)
#
# Run: 1283, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 32, max: 117)
#
# Run: 1284, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 33.04, max: 118)
#
# Run: 1285, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 34.6, max: 169)
#
# Run: 1286, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 35.63, max: 169)
#
# Run: 1287, exploration: 0.01, score: 102
# Scores: (min: 9, avg: 36.1, max: 169)
#
# Run: 1288, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 35.5, max: 169)
#
# Run: 1289, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 36.02, max: 169)
#
# Run: 1290, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 35.56, max: 169)
#
# Run: 1291, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 35.35, max: 169)
#
# Run: 1292, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 36.44, max: 176)
#
# Run: 1293, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 37.25, max: 176)
#
# Run: 1294, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 37.86, max: 176)
#
# Run: 1295, exploration: 0.01, score: 102
# Scores: (min: 9, avg: 37.97, max: 176)
#
# Run: 1296, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 38.88, max: 176)
#
# Run: 1297, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 38.22, max: 176)
#
# Run: 1298, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 38.14, max: 176)
#
# Run: 1299, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 37.83, max: 176)
#
# Run: 1300, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 37.58, max: 176)
#
# Run: 1301, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 37.23, max: 176)
#
# Run: 1302, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 36.91, max: 176)
#
# Run: 1303, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.79, max: 176)
#
# Run: 1304, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 36.7, max: 176)
#
# Run: 1305, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.42, max: 176)
#
# Run: 1306, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 36.38, max: 176)
#
# Run: 1307, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 36.31, max: 176)
#
# Run: 1308, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.3, max: 176)
#
# Run: 1309, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.31, max: 176)
#
# Run: 1310, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.32, max: 176)
#
# Run: 1311, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.32, max: 176)
#
# Run: 1312, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.82, max: 176)
#
# Run: 1313, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.66, max: 176)
#
# Run: 1314, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.61, max: 176)
#
# Run: 1315, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 35.54, max: 176)
#
# Run: 1316, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.2, max: 176)
#
# Run: 1317, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.19, max: 176)
#
# Run: 1318, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.97, max: 176)
#
# Run: 1319, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.84, max: 176)
#
# Run: 1320, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.51, max: 176)
#
# Run: 1321, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 34.45, max: 176)
#
# Run: 1322, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.38, max: 176)
#
# Run: 1323, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 34.3, max: 176)
#
# Run: 1324, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.68, max: 176)
#
# Run: 1325, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 33.61, max: 176)
#
# Run: 1326, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.55, max: 176)
#
# Run: 1327, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.92, max: 176)
#
# Run: 1328, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.7, max: 176)
#
# Run: 1329, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.2, max: 176)
#
# Run: 1330, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.96, max: 176)
#
# Run: 1331, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.83, max: 176)
#
# Run: 1332, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 31.84, max: 176)
#
# Run: 1333, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.84, max: 176)
#
# Run: 1334, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.64, max: 176)
#
# Run: 1335, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 31.48, max: 176)
#
# Run: 1336, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.44, max: 176)
#
# Run: 1337, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 31.2, max: 176)
#
# Run: 1338, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 30.36, max: 176)
#
# Run: 1339, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 31.06, max: 176)
#
# Run: 1340, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 31.19, max: 176)
#
# Run: 1341, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 30.64, max: 176)
#
# Run: 1342, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 30.7, max: 176)
#
# Run: 1343, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 30.35, max: 176)
#
# Run: 1344, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 30.36, max: 176)
#
# Run: 1345, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 30.39, max: 176)
#
# Run: 1346, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 30.19, max: 176)
#
# Run: 1347, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 30.18, max: 176)
#
# Run: 1348, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 30.27, max: 176)
#
# Run: 1349, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.26, max: 176)
#
# Run: 1350, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 30.4, max: 176)
#
# Run: 1351, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 30.57, max: 176)
#
# Run: 1352, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 30.5, max: 176)
#
# Run: 1353, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 30.6, max: 176)
#
# Run: 1354, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 30.5, max: 176)
#
# Run: 1355, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 30.46, max: 176)
#
# Run: 1356, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 30.46, max: 176)
#
# Run: 1357, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.39, max: 176)
#
# Run: 1358, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 30.32, max: 176)
#
# Run: 1359, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 30.16, max: 176)
#
# Run: 1360, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 30.17, max: 176)
#
# Run: 1361, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 30.33, max: 176)
#
# Run: 1362, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 30.37, max: 176)
#
# Run: 1363, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 30.72, max: 176)
#
# Run: 1364, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 30.87, max: 176)
#
# Run: 1365, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 30.95, max: 176)
#
# Run: 1366, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 30.97, max: 176)
#
# Run: 1367, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 31.08, max: 176)
#
# Run: 1368, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 32.23, max: 183)
#
# Run: 1369, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 32.64, max: 183)
#
# Run: 1370, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 33.2, max: 183)
#
# Run: 1371, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 33.95, max: 183)
#
# Run: 1372, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 33.92, max: 183)
#
# Run: 1373, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 34.66, max: 183)
#
# Run: 1374, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 35.41, max: 183)
#
# Run: 1375, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 36.26, max: 183)
#
# Run: 1376, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 36.31, max: 183)
#
# Run: 1377, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 35.85, max: 183)
#
# Run: 1378, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 37.06, max: 183)
#
# Run: 1379, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 38.28, max: 183)
#
# Run: 1380, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 38.65, max: 183)
#
# Run: 1381, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 40.46, max: 196)
#
# Run: 1382, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 41.21, max: 196)
#
# Run: 1383, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 40.41, max: 196)
#
# Run: 1384, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 39.54, max: 196)
#
# Run: 1385, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 38.69, max: 196)
#
# Run: 1386, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 38.89, max: 196)
#
# Run: 1387, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 38.5, max: 196)
#
# Run: 1388, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 38.24, max: 196)
#
# Run: 1389, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 39.08, max: 196)
#
# Run: 1390, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 39.26, max: 196)
#
# Run: 1391, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 39.26, max: 196)
#
# Run: 1392, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 38.66, max: 196)
#
# Run: 1393, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 39.49, max: 196)
#
# Run: 1394, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 39.05, max: 196)
#
# Run: 1395, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 38.82, max: 196)
#
# Run: 1396, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 38.54, max: 196)
#
# Run: 1397, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 39.56, max: 196)
#
# Run: 1398, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 40.85, max: 196)
#
# Run: 1399, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 42.1, max: 196)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-13-136ffdafa568> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#      89
#
# <ipython-input-13-136ffdafa568> in experience_replay(self)
#      53             q_update = reward
#      54             if not terminal:
# ---> 55                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3719               'You must feed a value for placeholder %s' % (tensor,))
#    3720       if not isinstance(value, ops.Tensor):
# -> 3721         value = ops.convert_to_tensor(value, dtype=tensor.dtype)
#    3722       if value.dtype != tensor.dtype:
#    3723         # Temporary workaround due to `convert_to_tensor` not casting floats.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1312
#    1313     if ret is None:
# -> 1314       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1315
#    1316     if ret is NotImplemented:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     256   """
#     257   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 258                         allow_broadcast=True)
#     259
#     260
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     264   ctx = context.context()
#     265   if ctx.executing_eagerly():
# --> 266     t = convert_to_eager_tensor(value, ctx, dtype)
#     267     if shape is None:
#     268       return t
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      94       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      95   ctx.ensure_initialized()
# ---> 96   return ops.EagerTensor(value, ctx.device_name, dtype)
#      97
#      98
#
# KeyboardInterrupt:

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.0001  #Adjusted learning rate smaller
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 11
# Scores: (min: 11, avg: 11, max: 11)
#
# Run: 2, exploration: 0.9558895783575597, score: 18
# Scores: (min: 11, avg: 14.5, max: 18)
#
# Run: 3, exploration: 0.9000874278732445, score: 13
# Scores: (min: 11, avg: 14, max: 18)
#
# Run: 4, exploration: 0.7111635524897149, score: 48
# Scores: (min: 11, avg: 22.5, max: 48)
#
# Run: 5, exploration: 0.6337242817644086, score: 24
# Scores: (min: 11, avg: 22.8, max: 48)
#
# Run: 6, exploration: 0.5790496471185967, score: 19
# Scores: (min: 11, avg: 22.166666666666668, max: 48)
#
# Run: 7, exploration: 0.5507399854171277, score: 11
# Scores: (min: 11, avg: 20.571428571428573, max: 48)
#
# Run: 8, exploration: 0.46677573701590436, score: 34
# Scores: (min: 11, avg: 22.25, max: 48)
#
# Run: 9, exploration: 0.39166620452737816, score: 36
# Scores: (min: 11, avg: 23.77777777777778, max: 48)
#
# Run: 10, exploration: 0.37251769488706843, score: 11
# Scores: (min: 11, avg: 22.5, max: 48)
#
# Run: 11, exploration: 0.3543053533848483, score: 11
# Scores: (min: 11, avg: 21.454545454545453, max: 48)
#
# Run: 12, exploration: 0.3386767948568688, score: 10
# Scores: (min: 10, avg: 20.5, max: 48)
#
# Run: 13, exploration: 0.3157247089126454, score: 15
# Scores: (min: 10, avg: 20.076923076923077, max: 48)
#
# Run: 14, exploration: 0.2987875242397482, score: 12
# Scores: (min: 10, avg: 19.5, max: 48)
#
# Run: 15, exploration: 0.2827589419554058, score: 12
# Scores: (min: 10, avg: 19, max: 48)
#
# Run: 16, exploration: 0.2702863258025825, score: 10
# Scores: (min: 10, avg: 18.4375, max: 48)
#
# Run: 17, exploration: 0.2583638820072446, score: 10
# Scores: (min: 10, avg: 17.941176470588236, max: 48)
#
# Run: 18, exploration: 0.2457325055235537, score: 11
# Scores: (min: 10, avg: 17.555555555555557, max: 48)
#
# Run: 19, exploration: 0.23489314109365644, score: 10
# Scores: (min: 10, avg: 17.157894736842106, max: 48)
#
# Run: 20, exploration: 0.22229219984074702, score: 12
# Scores: (min: 10, avg: 16.9, max: 48)
#
# Run: 21, exploration: 0.21248679717794605, score: 10
# Scores: (min: 10, avg: 16.571428571428573, max: 48)
#
# Run: 22, exploration: 0.2031139149609751, score: 10
# Scores: (min: 10, avg: 16.272727272727273, max: 48)
#
# Run: 23, exploration: 0.19611067854912728, score: 8
# Scores: (min: 8, avg: 15.91304347826087, max: 48)
#
# Run: 24, exploration: 0.18934890919900021, score: 8
# Scores: (min: 8, avg: 15.583333333333334, max: 48)
#
# Run: 25, exploration: 0.17740377510930716, score: 14
# Scores: (min: 8, avg: 15.52, max: 48)
#
# Run: 26, exploration: 0.1712870076899825, score: 8
# Scores: (min: 8, avg: 15.23076923076923, max: 48)
#
# Run: 27, exploration: 0.16291280823111093, score: 11
# Scores: (min: 8, avg: 15.074074074074074, max: 48)
#
# Run: 28, exploration: 0.15650920157696743, score: 9
# Scores: (min: 8, avg: 14.857142857142858, max: 48)
#
# Run: 29, exploration: 0.15111286553822956, score: 8
# Scores: (min: 8, avg: 14.620689655172415, max: 48)
#
# Run: 30, exploration: 0.1451730787173275, score: 9
# Scores: (min: 8, avg: 14.433333333333334, max: 48)
#
# Run: 31, exploration: 0.13738520790976036, score: 12
# Scores: (min: 8, avg: 14.35483870967742, max: 48)
#
# Run: 32, exploration: 0.13198501352907185, score: 9
# Scores: (min: 8, avg: 14.1875, max: 48)
#
# Run: 33, exploration: 0.12679708435358925, score: 9
# Scores: (min: 8, avg: 14.030303030303031, max: 48)
#
# Run: 34, exploration: 0.11939502647758558, score: 13
# Scores: (min: 8, avg: 14, max: 48)
#
# Run: 35, exploration: 0.11412846151764894, score: 10
# Scores: (min: 8, avg: 13.885714285714286, max: 48)
#
# Run: 36, exploration: 0.10964241905397228, score: 9
# Scores: (min: 8, avg: 13.75, max: 48)
#
# Run: 37, exploration: 0.10480604571960442, score: 10
# Scores: (min: 8, avg: 13.64864864864865, max: 48)
#
# Run: 38, exploration: 0.0996820918179746, score: 11
# Scores: (min: 8, avg: 13.578947368421053, max: 48)
#
# Run: 39, exploration: 0.09480864735409487, score: 11
# Scores: (min: 8, avg: 13.512820512820513, max: 48)
#
# Run: 40, exploration: 0.09017346495423652, score: 11
# Scores: (min: 8, avg: 13.45, max: 48)
#
# Run: 41, exploration: 0.08619587539414532, score: 10
# Scores: (min: 8, avg: 13.365853658536585, max: 48)
#
# Run: 42, exploration: 0.08157186144027828, score: 12
# Scores: (min: 8, avg: 13.333333333333334, max: 48)
#
# Run: 43, exploration: 0.07642587550895225, score: 14
# Scores: (min: 8, avg: 13.348837209302326, max: 48)
#
# Run: 44, exploration: 0.07268942442628039, score: 11
# Scores: (min: 8, avg: 13.295454545454545, max: 48)
#
# Run: 45, exploration: 0.06983222438783, score: 9
# Scores: (min: 8, avg: 13.2, max: 48)
#
# Run: 46, exploration: 0.06708733218678724, score: 9
# Scores: (min: 8, avg: 13.108695652173912, max: 48)
#
# Run: 47, exploration: 0.06412808167716157, score: 10
# Scores: (min: 8, avg: 13.042553191489361, max: 48)
#
# Run: 48, exploration: 0.06038446427088321, score: 13
# Scores: (min: 8, avg: 13.041666666666666, max: 48)
#
# Run: 49, exploration: 0.05772088009124167, score: 10
# Scores: (min: 8, avg: 12.979591836734693, max: 48)
#
# Run: 50, exploration: 0.0543512971290831, score: 13
# Scores: (min: 8, avg: 12.98, max: 48)
#
# Run: 51, exploration: 0.051178420962124486, score: 13
# Scores: (min: 8, avg: 12.980392156862745, max: 48)
#
# Run: 52, exploration: 0.048190768399801194, score: 13
# Scores: (min: 8, avg: 12.98076923076923, max: 48)
#
# Run: 53, exploration: 0.045605554379880814, score: 12
# Scores: (min: 8, avg: 12.962264150943396, max: 48)
#
# Run: 54, exploration: 0.04272851397543923, score: 14
# Scores: (min: 8, avg: 12.981481481481481, max: 48)
#
# Run: 55, exploration: 0.04043632488927963, score: 12
# Scores: (min: 8, avg: 12.963636363636363, max: 48)
#
# Run: 56, exploration: 0.0378853869148274, score: 14
# Scores: (min: 8, avg: 12.982142857142858, max: 48)
#
# Run: 57, exploration: 0.036396227662238566, score: 9
# Scores: (min: 8, avg: 12.912280701754385, max: 48)
#
# Run: 58, exploration: 0.03496560272750046, score: 9
# Scores: (min: 8, avg: 12.844827586206897, max: 48)
#
# Run: 59, exploration: 0.033423255248208356, score: 10
# Scores: (min: 8, avg: 12.796610169491526, max: 48)
#
# Run: 60, exploration: 0.03147209942303359, score: 13
# Scores: (min: 8, avg: 12.8, max: 48)
#
# Run: 61, exploration: 0.029783765425331846, score: 12
# Scores: (min: 8, avg: 12.78688524590164, max: 48)
#
# Run: 62, exploration: 0.0280450728002803, score: 13
# Scores: (min: 8, avg: 12.790322580645162, max: 48)
#
# Run: 63, exploration: 0.026673952849996664, score: 11
# Scores: (min: 8, avg: 12.761904761904763, max: 48)
#
# Run: 64, exploration: 0.02562548094765099, score: 9
# Scores: (min: 8, avg: 12.703125, max: 48)
#
# Run: 65, exploration: 0.02449513017825978, score: 10
# Scores: (min: 8, avg: 12.661538461538461, max: 48)
#
# Run: 66, exploration: 0.023414639657910272, score: 10
# Scores: (min: 8, avg: 12.621212121212121, max: 48)
#
# Run: 67, exploration: 0.022381810029994047, score: 10
# Scores: (min: 8, avg: 12.582089552238806, max: 48)
#
# Run: 68, exploration: 0.021394538952450012, score: 10
# Scores: (min: 8, avg: 12.544117647058824, max: 48)
#
# Run: 69, exploration: 0.020450816818411825, score: 10
# Scores: (min: 8, avg: 12.507246376811594, max: 48)
#
# Run: 70, exploration: 0.01964695745288379, score: 9
# Scores: (min: 8, avg: 12.457142857142857, max: 48)
#
# Run: 71, exploration: 0.018780321875645996, score: 10
# Scores: (min: 8, avg: 12.422535211267606, max: 48)
#
# Run: 72, exploration: 0.018042124582040707, score: 9
# Scores: (min: 8, avg: 12.375, max: 48)
#
# Run: 73, exploration: 0.017332943577287888, score: 9
# Scores: (min: 8, avg: 12.32876712328767, max: 48)
#
# Run: 74, exploration: 0.0165683801277891, score: 10
# Scores: (min: 8, avg: 12.297297297297296, max: 48)
#
# Run: 75, exploration: 0.015917127532080494, score: 9
# Scores: (min: 8, avg: 12.253333333333334, max: 48)
#
# Run: 76, exploration: 0.015215016325303928, score: 10
# Scores: (min: 8, avg: 12.223684210526315, max: 48)
#
# Run: 77, exploration: 0.014690412403624311, score: 8
# Scores: (min: 8, avg: 12.168831168831169, max: 48)
#
# Run: 78, exploration: 0.014042412118399107, score: 10
# Scores: (min: 8, avg: 12.14102564102564, max: 48)
#
# Run: 79, exploration: 0.013558238831322046, score: 8
# Scores: (min: 8, avg: 12.08860759493671, max: 48)
#
# Run: 80, exploration: 0.01302530572838545, score: 9
# Scores: (min: 8, avg: 12.05, max: 48)
#
# Run: 81, exploration: 0.012388500230681249, score: 11
# Scores: (min: 8, avg: 12.037037037037036, max: 48)
#
# Run: 82, exploration: 0.01184203826198843, score: 10
# Scores: (min: 8, avg: 12.012195121951219, max: 48)
#
# Run: 83, exploration: 0.011319680961146208, score: 10
# Scores: (min: 8, avg: 11.987951807228916, max: 48)
#
# Run: 84, exploration: 0.010874738754866477, score: 9
# Scores: (min: 8, avg: 11.952380952380953, max: 48)
#
# Run: 85, exploration: 0.010447285872500434, score: 9
# Scores: (min: 8, avg: 11.91764705882353, max: 48)
#
# Run: 86, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.895348837209303, max: 48)
#
# Run: 87, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.873563218390805, max: 48)
#
# Run: 88, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.829545454545455, max: 48)
#
# Run: 89, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.797752808988765, max: 48)
#
# Run: 90, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.766666666666667, max: 48)
#
# Run: 91, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.725274725274724, max: 48)
#
# Run: 92, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.695652173913043, max: 48)
#
# Run: 93, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.666666666666666, max: 48)
#
# Run: 94, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.638297872340425, max: 48)
#
# Run: 95, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.621052631578948, max: 48)
#
# Run: 96, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.59375, max: 48)
#
# Run: 97, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.56701030927835, max: 48)
#
# Run: 98, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.540816326530612, max: 48)
#
# Run: 99, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.525252525252526, max: 48)
#
# Run: 100, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.5, max: 48)
#
# Run: 101, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.47, max: 48)
#
# Run: 102, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.39, max: 48)
#
# Run: 103, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.34, max: 48)
#
# Run: 104, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.95, max: 36)
#
# Run: 105, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.81, max: 36)
#
# Run: 106, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.7, max: 36)
#
# Run: 107, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.7, max: 36)
#
# Run: 108, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.46, max: 36)
#
# Run: 109, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.19, max: 15)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.18, max: 15)
#
# Run: 111, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.17, max: 15)
#
# Run: 112, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.17, max: 15)
#
# Run: 113, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.13, max: 14)
#
# Run: 114, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.11, max: 14)
#
# Run: 115, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.08, max: 14)
#
# Run: 116, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.06, max: 14)
#
# Run: 117, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.06, max: 14)
#
# Run: 118, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.05, max: 14)
#
# Run: 119, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.05, max: 14)
#
# Run: 120, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.03, max: 14)
#
# Run: 121, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.03, max: 14)
#
# Run: 122, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.04, max: 14)
#
# Run: 123, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.06, max: 14)
#
# Run: 124, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.07, max: 14)
#
# Run: 125, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.02, max: 14)
#
# Run: 126, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.06, max: 14)
#
# Run: 127, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.03, max: 14)
#
# Run: 128, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.02, max: 14)
#
# Run: 129, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.03, max: 14)
#
# Run: 130, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.04, max: 14)
#
# Run: 131, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.01, max: 14)
#
# Run: 132, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.07, max: 15)
#
# Run: 133, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.07, max: 15)
#
# Run: 134, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.03, max: 15)
#
# Run: 135, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.03, max: 15)
#
# Run: 136, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.03, max: 15)
#
# Run: 137, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.03, max: 15)
#
# Run: 138, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.02, max: 15)
#
# Run: 139, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.99, max: 15)
#
# Run: 140, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.97, max: 15)
#
# Run: 141, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.96, max: 15)
#
# Run: 142, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.94, max: 15)
#
# Run: 143, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.92, max: 15)
#
# Run: 144, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 10.05, max: 24)
#
# Run: 145, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.05, max: 24)
#
# Run: 146, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.07, max: 24)
#
# Run: 147, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.06, max: 24)
#
# Run: 148, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.01, max: 24)
#
# Run: 149, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.02, max: 24)
#
# Run: 150, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10, max: 24)
#
# Run: 151, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.01, max: 24)
#
# Run: 152, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.97, max: 24)
#
# Run: 153, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10, max: 24)
#
# Run: 154, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.01, max: 24)
#
# Run: 155, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.07, max: 24)
#
# Run: 156, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.05, max: 24)
#
# Run: 157, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 10.12, max: 24)
#
# Run: 158, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 10.22, max: 24)
#
# Run: 159, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.25, max: 24)
#
# Run: 160, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 10.31, max: 24)
#
# Run: 161, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.34, max: 24)
#
# Run: 162, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 10.43, max: 24)
#
# Run: 163, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 10.49, max: 24)
#
# Run: 164, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.53, max: 24)
#
# Run: 165, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.56, max: 24)
#
# Run: 166, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.6, max: 24)
#
# Run: 167, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 10.66, max: 24)
#
# Run: 168, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.74, max: 24)
#
# Run: 169, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 10.89, max: 25)
#
# Run: 170, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.98, max: 25)
#
# Run: 171, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.03, max: 25)
#
# Run: 172, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.08, max: 25)
#
# Run: 173, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.17, max: 25)
#
# Run: 174, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.24, max: 25)
#
# Run: 175, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 11.34, max: 25)
#
# Run: 176, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 11.48, max: 25)
#
# Run: 177, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.62, max: 25)
#
# Run: 178, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.69, max: 25)
#
# Run: 179, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.83, max: 25)
#
# Run: 180, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.94, max: 25)
#
# Run: 181, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.06, max: 25)
#
# Run: 182, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 12.2, max: 25)
#
# Run: 183, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 12.38, max: 28)
#
# Run: 184, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.52, max: 28)
#
# Run: 185, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.66, max: 28)
#
# Run: 186, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.79, max: 28)
#
# Run: 187, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.91, max: 28)
#
# Run: 188, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.03, max: 28)
#
# Run: 189, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 13.13, max: 28)
#
# Run: 190, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.21, max: 28)
#
# Run: 191, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 13.44, max: 31)
#
# Run: 192, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.52, max: 31)
#
# Run: 193, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 13.64, max: 31)
#
# Run: 194, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 13.76, max: 31)
#
# Run: 195, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 13.94, max: 31)
#
# Run: 196, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 14.06, max: 31)
#
# Run: 197, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.23, max: 31)
#
# Run: 198, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 14.35, max: 31)
#
# Run: 199, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.44, max: 31)
#
# Run: 200, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 14.65, max: 31)
#
# Run: 201, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.83, max: 31)
#
# Run: 202, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 14.96, max: 31)
#
# Run: 203, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 15.26, max: 38)
#
# Run: 204, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 15.48, max: 38)
#
# Run: 205, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.62, max: 38)
#
# Run: 206, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 15.81, max: 38)
#
# Run: 207, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 16.04, max: 38)
#
# Run: 208, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.14, max: 38)
#
# Run: 209, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.26, max: 38)
#
# Run: 210, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 16.47, max: 38)
#
# Run: 211, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 16.67, max: 38)
#
# Run: 212, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 16.94, max: 38)
#
# Run: 213, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 18.16, max: 133)
#
# Run: 214, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 18.39, max: 133)
#
# Run: 215, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 18.56, max: 133)
#
# Run: 216, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 18.72, max: 133)
#
# Run: 217, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 18.89, max: 133)
#
# Run: 218, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 19.13, max: 133)
#
# Run: 219, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 19.28, max: 133)
#
# Run: 220, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 19.66, max: 133)
#
# Run: 221, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 19.91, max: 133)
#
# Run: 222, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 20.1, max: 133)
#
# Run: 223, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 20.4, max: 133)
#
# Run: 224, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 20.69, max: 133)
#
# Run: 225, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 20.99, max: 133)
#
# Run: 226, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 21.41, max: 133)
#
# Run: 227, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 21.77, max: 133)
#
# Run: 228, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 22.08, max: 133)
#
# Run: 229, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 22.25, max: 133)
#
# Run: 230, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 22.76, max: 133)
#
# Run: 231, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 23.08, max: 133)
#
# Run: 232, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 23.25, max: 133)
#
# Run: 233, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 23.7, max: 133)
#
# Run: 234, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 24.03, max: 133)
#
# Run: 235, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 24.23, max: 133)
#
# Run: 236, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 24.44, max: 133)
#
# Run: 237, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 24.71, max: 133)
#
# Run: 238, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 24.98, max: 133)
#
# Run: 239, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 25.34, max: 133)
#
# Run: 240, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 25.59, max: 133)
#
# Run: 241, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 25.98, max: 133)
#
# Run: 242, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 26.24, max: 133)
#
# Run: 243, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 26.62, max: 133)
#
# Run: 244, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 27.09, max: 133)
#
# Run: 245, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 27.45, max: 133)
#
# Run: 246, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 27.7, max: 133)
#
# Run: 247, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 27.94, max: 133)
#
# Run: 248, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 28.57, max: 133)
#
# Run: 249, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 29.39, max: 133)
#
# Run: 250, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 29.73, max: 133)
#
# Run: 251, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 30.26, max: 133)
#
# Run: 252, exploration: 0.01, score: 60
# Scores: (min: 12, avg: 30.77, max: 133)
#
# Run: 253, exploration: 0.01, score: 57
# Scores: (min: 12, avg: 31.19, max: 133)
#
# Run: 254, exploration: 0.01, score: 45
# Scores: (min: 12, avg: 31.49, max: 133)
#
# Run: 255, exploration: 0.01, score: 41
# Scores: (min: 12, avg: 31.72, max: 133)
#
# Run: 256, exploration: 0.01, score: 49
# Scores: (min: 13, avg: 32.09, max: 133)
#
# Run: 257, exploration: 0.01, score: 48
# Scores: (min: 13, avg: 32.41, max: 133)
#
# Run: 258, exploration: 0.01, score: 51
# Scores: (min: 13, avg: 32.73, max: 133)
#
# Run: 259, exploration: 0.01, score: 103
# Scores: (min: 13, avg: 33.63, max: 133)
#
# Run: 260, exploration: 0.01, score: 49
# Scores: (min: 13, avg: 33.93, max: 133)
#
# Run: 261, exploration: 0.01, score: 88
# Scores: (min: 13, avg: 34.66, max: 133)
#
# Run: 262, exploration: 0.01, score: 48
# Scores: (min: 13, avg: 34.92, max: 133)
#
# Run: 263, exploration: 0.01, score: 42
# Scores: (min: 13, avg: 35.17, max: 133)
#
# Run: 264, exploration: 0.01, score: 44
# Scores: (min: 13, avg: 35.48, max: 133)
#
# Run: 265, exploration: 0.01, score: 50
# Scores: (min: 14, avg: 35.85, max: 133)
#
# Run: 266, exploration: 0.01, score: 66
# Scores: (min: 14, avg: 36.37, max: 133)
#
# Run: 267, exploration: 0.01, score: 86
# Scores: (min: 14, avg: 37.07, max: 133)
#
# Run: 268, exploration: 0.01, score: 62
# Scores: (min: 14, avg: 37.51, max: 133)
#
# Run: 269, exploration: 0.01, score: 65
# Scores: (min: 14, avg: 37.91, max: 133)
#
# Run: 270, exploration: 0.01, score: 88
# Scores: (min: 14, avg: 38.61, max: 133)
#
# Run: 271, exploration: 0.01, score: 48
# Scores: (min: 14, avg: 38.94, max: 133)
#
# Run: 272, exploration: 0.01, score: 40
# Scores: (min: 17, avg: 39.2, max: 133)
#
# Run: 273, exploration: 0.01, score: 86
# Scores: (min: 17, avg: 39.88, max: 133)
#
# Run: 274, exploration: 0.01, score: 42
# Scores: (min: 17, avg: 40.13, max: 133)
#
# Run: 275, exploration: 0.01, score: 56
# Scores: (min: 17, avg: 40.5, max: 133)
#
# Run: 276, exploration: 0.01, score: 62
# Scores: (min: 17, avg: 40.88, max: 133)
#
# Run: 277, exploration: 0.01, score: 62
# Scores: (min: 17, avg: 41.28, max: 133)
#
# Run: 278, exploration: 0.01, score: 74
# Scores: (min: 17, avg: 41.85, max: 133)
#
# Run: 279, exploration: 0.01, score: 115
# Scores: (min: 17, avg: 42.78, max: 133)
#
# Run: 280, exploration: 0.01, score: 73
# Scores: (min: 17, avg: 43.31, max: 133)
#
# Run: 281, exploration: 0.01, score: 63
# Scores: (min: 17, avg: 43.71, max: 133)
#
# Run: 282, exploration: 0.01, score: 59
# Scores: (min: 17, avg: 44.06, max: 133)
#
# Run: 283, exploration: 0.01, score: 58
# Scores: (min: 17, avg: 44.36, max: 133)
#
# Run: 284, exploration: 0.01, score: 60
# Scores: (min: 17, avg: 44.73, max: 133)
#
# Run: 285, exploration: 0.01, score: 68
# Scores: (min: 17, avg: 45.18, max: 133)
#
# Run: 286, exploration: 0.01, score: 62
# Scores: (min: 17, avg: 45.57, max: 133)
#
# Run: 287, exploration: 0.01, score: 70
# Scores: (min: 17, avg: 46.05, max: 133)
#
# Run: 288, exploration: 0.01, score: 72
# Scores: (min: 17, avg: 46.57, max: 133)
#
# Run: 289, exploration: 0.01, score: 94
# Scores: (min: 17, avg: 47.32, max: 133)
#
# Run: 290, exploration: 0.01, score: 84
# Scores: (min: 17, avg: 47.99, max: 133)
#
# Run: 291, exploration: 0.01, score: 66
# Scores: (min: 17, avg: 48.34, max: 133)
#
# Run: 292, exploration: 0.01, score: 72
# Scores: (min: 19, avg: 48.89, max: 133)
#
# Run: 293, exploration: 0.01, score: 70
# Scores: (min: 19, avg: 49.38, max: 133)
#
# Run: 294, exploration: 0.01, score: 115
# Scores: (min: 19, avg: 50.32, max: 133)
#
# Run: 295, exploration: 0.01, score: 90
# Scores: (min: 19, avg: 50.94, max: 133)
#
# Run: 296, exploration: 0.01, score: 83
# Scores: (min: 19, avg: 51.56, max: 133)
#
# Run: 297, exploration: 0.01, score: 79
# Scores: (min: 19, avg: 52.09, max: 133)
#
# Run: 298, exploration: 0.01, score: 66
# Scores: (min: 19, avg: 52.54, max: 133)
#
# Run: 299, exploration: 0.01, score: 74
# Scores: (min: 20, avg: 53.09, max: 133)
#
# Run: 300, exploration: 0.01, score: 82
# Scores: (min: 20, avg: 53.61, max: 133)
#
# Run: 301, exploration: 0.01, score: 78
# Scores: (min: 20, avg: 54.13, max: 133)
#
# Run: 302, exploration: 0.01, score: 84
# Scores: (min: 20, avg: 54.74, max: 133)
#
# Run: 303, exploration: 0.01, score: 94
# Scores: (min: 20, avg: 55.3, max: 133)
#
# Run: 304, exploration: 0.01, score: 101
# Scores: (min: 20, avg: 56, max: 133)
#
# Run: 305, exploration: 0.01, score: 84
# Scores: (min: 20, avg: 56.6, max: 133)
#
# Run: 306, exploration: 0.01, score: 103
# Scores: (min: 20, avg: 57.36, max: 133)
#
# Run: 307, exploration: 0.01, score: 97
# Scores: (min: 20, avg: 57.99, max: 133)
#
# Run: 308, exploration: 0.01, score: 111
# Scores: (min: 21, avg: 58.9, max: 133)
#
# Run: 309, exploration: 0.01, score: 118
# Scores: (min: 24, avg: 59.87, max: 133)
#
# Run: 310, exploration: 0.01, score: 151
# Scores: (min: 24, avg: 61.07, max: 151)
#
# Run: 311, exploration: 0.01, score: 109
# Scores: (min: 24, avg: 61.86, max: 151)
#
# Run: 312, exploration: 0.01, score: 139
# Scores: (min: 24, avg: 62.88, max: 151)
#
# Run: 313, exploration: 0.01, score: 132
# Scores: (min: 24, avg: 62.87, max: 151)
#
# Run: 314, exploration: 0.01, score: 95
# Scores: (min: 24, avg: 63.49, max: 151)
#
# Run: 315, exploration: 0.01, score: 138
# Scores: (min: 24, avg: 64.61, max: 151)
#
# Run: 316, exploration: 0.01, score: 119
# Scores: (min: 25, avg: 65.56, max: 151)
#
# Run: 317, exploration: 0.01, score: 125
# Scores: (min: 25, avg: 66.54, max: 151)
#
# Run: 318, exploration: 0.01, score: 179
# Scores: (min: 25, avg: 67.99, max: 179)
#
# Run: 319, exploration: 0.01, score: 115
# Scores: (min: 26, avg: 68.89, max: 179)
#
# Run: 320, exploration: 0.01, score: 99
# Scores: (min: 26, avg: 69.4, max: 179)
#
# Run: 321, exploration: 0.01, score: 150
# Scores: (min: 26, avg: 70.55, max: 179)
#
# Run: 322, exploration: 0.01, score: 138
# Scores: (min: 26, avg: 71.63, max: 179)
#
# Run: 323, exploration: 0.01, score: 101
# Scores: (min: 26, avg: 72.24, max: 179)
#
# Run: 324, exploration: 0.01, score: 116
# Scores: (min: 26, avg: 73.02, max: 179)
#
# Run: 325, exploration: 0.01, score: 97
# Scores: (min: 26, avg: 73.6, max: 179)
#
# Run: 326, exploration: 0.01, score: 128
# Scores: (min: 26, avg: 74.34, max: 179)
#
# Run: 327, exploration: 0.01, score: 145
# Scores: (min: 26, avg: 75.35, max: 179)
#
# Run: 328, exploration: 0.01, score: 158
# Scores: (min: 26, avg: 76.54, max: 179)
#
# Run: 329, exploration: 0.01, score: 132
# Scores: (min: 30, avg: 77.6, max: 179)
#
# Run: 330, exploration: 0.01, score: 126
# Scores: (min: 30, avg: 78.25, max: 179)
#
# Run: 331, exploration: 0.01, score: 118
# Scores: (min: 30, avg: 79.02, max: 179)
#
# Run: 332, exploration: 0.01, score: 181
# Scores: (min: 30, avg: 80.51, max: 181)
#
# Run: 333, exploration: 0.01, score: 133
# Scores: (min: 30, avg: 81.3, max: 181)
#
# Run: 334, exploration: 0.01, score: 134
# Scores: (min: 30, avg: 82.22, max: 181)
#
# Run: 335, exploration: 0.01, score: 139
# Scores: (min: 30, avg: 83.31, max: 181)
#
# Run: 336, exploration: 0.01, score: 169
# Scores: (min: 33, avg: 84.7, max: 181)
#
# Run: 337, exploration: 0.01, score: 145
# Scores: (min: 33, avg: 85.78, max: 181)
#
# Run: 338, exploration: 0.01, score: 156
# Scores: (min: 33, avg: 86.97, max: 181)
#
# Run: 339, exploration: 0.01, score: 151
# Scores: (min: 33, avg: 88.04, max: 181)
#
# Run: 340, exploration: 0.01, score: 201
# Scores: (min: 33, avg: 89.71, max: 201)
#
# Run: 341, exploration: 0.01, score: 201
# Scores: (min: 33, avg: 91.24, max: 201)
#
# Run: 342, exploration: 0.01, score: 177
# Scores: (min: 33, avg: 92.65, max: 201)
#
# Run: 343, exploration: 0.01, score: 222
# Scores: (min: 33, avg: 94.37, max: 222)
#
# Run: 344, exploration: 0.01, score: 173
# Scores: (min: 33, avg: 95.39, max: 222)
#
# Run: 345, exploration: 0.01, score: 200
# Scores: (min: 33, avg: 96.94, max: 222)
#
# Run: 346, exploration: 0.01, score: 232
# Scores: (min: 33, avg: 98.9, max: 232)
#
# Run: 347, exploration: 0.01, score: 192
# Scores: (min: 40, avg: 100.49, max: 232)
#
# Run: 348, exploration: 0.01, score: 183
# Scores: (min: 40, avg: 101.61, max: 232)
#
# Run: 349, exploration: 0.01, score: 185
# Scores: (min: 40, avg: 102.53, max: 232)
#
# Run: 350, exploration: 0.01, score: 216
# Scores: (min: 40, avg: 104.24, max: 232)
#
# Run: 351, exploration: 0.01, score: 206
# Scores: (min: 40, avg: 105.63, max: 232)
#
# Run: 352, exploration: 0.01, score: 182
# Scores: (min: 40, avg: 106.85, max: 232)
#
# Run: 353, exploration: 0.01, score: 177
# Scores: (min: 40, avg: 108.05, max: 232)
#
# Run: 354, exploration: 0.01, score: 258
# Scores: (min: 40, avg: 110.18, max: 258)
#
# Run: 355, exploration: 0.01, score: 191
# Scores: (min: 40, avg: 111.68, max: 258)
#
# Run: 356, exploration: 0.01, score: 167
# Scores: (min: 40, avg: 112.86, max: 258)
#
# Run: 357, exploration: 0.01, score: 213
# Scores: (min: 40, avg: 114.51, max: 258)
#
# Run: 358, exploration: 0.01, score: 251
# Scores: (min: 40, avg: 116.51, max: 258)
#
# Run: 359, exploration: 0.01, score: 165
# Scores: (min: 40, avg: 117.13, max: 258)
#
# Run: 360, exploration: 0.01, score: 220
# Scores: (min: 40, avg: 118.84, max: 258)
#
# Run: 361, exploration: 0.01, score: 221
# Scores: (min: 40, avg: 120.17, max: 258)
#
# Run: 362, exploration: 0.01, score: 255
# Scores: (min: 40, avg: 122.24, max: 258)
#
# Run: 363, exploration: 0.01, score: 197
# Scores: (min: 40, avg: 123.79, max: 258)
#
# Run: 364, exploration: 0.01, score: 191
# Scores: (min: 40, avg: 125.26, max: 258)
#
# Run: 365, exploration: 0.01, score: 163
# Scores: (min: 40, avg: 126.39, max: 258)
#
# Run: 366, exploration: 0.01, score: 140
# Scores: (min: 40, avg: 127.13, max: 258)
#
# Run: 367, exploration: 0.01, score: 170
# Scores: (min: 40, avg: 127.97, max: 258)
#
# Run: 368, exploration: 0.01, score: 192
# Scores: (min: 40, avg: 129.27, max: 258)
#
# Run: 369, exploration: 0.01, score: 163
# Scores: (min: 40, avg: 130.25, max: 258)
#
# Run: 370, exploration: 0.01, score: 154
# Scores: (min: 40, avg: 130.91, max: 258)
#
# Run: 371, exploration: 0.01, score: 163
# Scores: (min: 40, avg: 132.06, max: 258)
#
# Run: 372, exploration: 0.01, score: 220
# Scores: (min: 42, avg: 133.86, max: 258)
#
# Run: 373, exploration: 0.01, score: 181
# Scores: (min: 42, avg: 134.81, max: 258)
#
# Run: 374, exploration: 0.01, score: 157
# Scores: (min: 56, avg: 135.96, max: 258)
#
# Run: 375, exploration: 0.01, score: 166
# Scores: (min: 58, avg: 137.06, max: 258)
#
# Run: 376, exploration: 0.01, score: 151
# Scores: (min: 58, avg: 137.95, max: 258)
#
# Run: 377, exploration: 0.01, score: 165
# Scores: (min: 58, avg: 138.98, max: 258)
#
# Run: 378, exploration: 0.01, score: 208
# Scores: (min: 58, avg: 140.32, max: 258)
#
# Run: 379, exploration: 0.01, score: 175
# Scores: (min: 58, avg: 140.92, max: 258)
#
# Run: 380, exploration: 0.01, score: 161
# Scores: (min: 58, avg: 141.8, max: 258)
#
# Run: 381, exploration: 0.01, score: 160
# Scores: (min: 58, avg: 142.77, max: 258)
#
# Run: 382, exploration: 0.01, score: 160
# Scores: (min: 58, avg: 143.78, max: 258)
#
# Run: 383, exploration: 0.01, score: 176
# Scores: (min: 60, avg: 144.96, max: 258)
#
# Run: 384, exploration: 0.01, score: 156
# Scores: (min: 62, avg: 145.92, max: 258)
#
# Run: 385, exploration: 0.01, score: 182
# Scores: (min: 62, avg: 147.06, max: 258)
#
# Run: 386, exploration: 0.01, score: 168
# Scores: (min: 66, avg: 148.12, max: 258)
#
# Run: 387, exploration: 0.01, score: 164
# Scores: (min: 66, avg: 149.06, max: 258)
#
# Run: 388, exploration: 0.01, score: 150
# Scores: (min: 66, avg: 149.84, max: 258)
#
# Run: 389, exploration: 0.01, score: 152
# Scores: (min: 66, avg: 150.42, max: 258)
#
# Run: 390, exploration: 0.01, score: 162
# Scores: (min: 66, avg: 151.2, max: 258)
#
# Run: 391, exploration: 0.01, score: 165
# Scores: (min: 66, avg: 152.19, max: 258)
#
# Run: 392, exploration: 0.01, score: 175
# Scores: (min: 66, avg: 153.22, max: 258)
#
# Run: 393, exploration: 0.01, score: 168
# Scores: (min: 66, avg: 154.2, max: 258)
#
# Run: 394, exploration: 0.01, score: 147
# Scores: (min: 66, avg: 154.52, max: 258)
#
# Run: 395, exploration: 0.01, score: 152
# Scores: (min: 66, avg: 155.14, max: 258)
#
# Run: 396, exploration: 0.01, score: 193
# Scores: (min: 66, avg: 156.24, max: 258)
#
# Run: 397, exploration: 0.01, score: 171
# Scores: (min: 66, avg: 157.16, max: 258)
#
# Run: 398, exploration: 0.01, score: 155
# Scores: (min: 74, avg: 158.05, max: 258)
#
# Run: 399, exploration: 0.01, score: 155
# Scores: (min: 78, avg: 158.86, max: 258)
#
# Run: 400, exploration: 0.01, score: 157
# Scores: (min: 78, avg: 159.61, max: 258)
#
# Run: 401, exploration: 0.01, score: 165
# Scores: (min: 84, avg: 160.48, max: 258)
#
# Run: 402, exploration: 0.01, score: 157
# Scores: (min: 84, avg: 161.21, max: 258)
#
# Run: 403, exploration: 0.01, score: 142
# Scores: (min: 84, avg: 161.69, max: 258)
#
# Run: 404, exploration: 0.01, score: 174
# Scores: (min: 84, avg: 162.42, max: 258)
#
# Run: 405, exploration: 0.01, score: 165
# Scores: (min: 95, avg: 163.23, max: 258)
#
# Run: 406, exploration: 0.01, score: 193
# Scores: (min: 95, avg: 164.13, max: 258)
#
# Run: 407, exploration: 0.01, score: 153
# Scores: (min: 95, avg: 164.69, max: 258)
#
# Run: 408, exploration: 0.01, score: 190
# Scores: (min: 95, avg: 165.48, max: 258)
#
# Run: 409, exploration: 0.01, score: 158
# Scores: (min: 95, avg: 165.88, max: 258)
#
# Run: 410, exploration: 0.01, score: 159
# Scores: (min: 95, avg: 165.96, max: 258)
#
# Run: 411, exploration: 0.01, score: 153
# Scores: (min: 95, avg: 166.4, max: 258)
#
# Run: 412, exploration: 0.01, score: 162
# Scores: (min: 95, avg: 166.63, max: 258)
#
# Run: 413, exploration: 0.01, score: 166
# Scores: (min: 95, avg: 166.97, max: 258)
#
# Run: 414, exploration: 0.01, score: 147
# Scores: (min: 97, avg: 167.49, max: 258)
#
# Run: 415, exploration: 0.01, score: 160
# Scores: (min: 97, avg: 167.71, max: 258)
#
# Run: 416, exploration: 0.01, score: 151
# Scores: (min: 97, avg: 168.03, max: 258)
#
# Run: 417, exploration: 0.01, score: 166
# Scores: (min: 97, avg: 168.44, max: 258)
#
# Run: 418, exploration: 0.01, score: 147
# Scores: (min: 97, avg: 168.12, max: 258)
#
# Run: 419, exploration: 0.01, score: 136
# Scores: (min: 97, avg: 168.33, max: 258)
#
# Run: 420, exploration: 0.01, score: 167
# Scores: (min: 97, avg: 169.01, max: 258)
#
# Run: 421, exploration: 0.01, score: 149
# Scores: (min: 97, avg: 169, max: 258)
#
# Run: 422, exploration: 0.01, score: 143
# Scores: (min: 97, avg: 169.05, max: 258)
#
# Run: 423, exploration: 0.01, score: 155
# Scores: (min: 97, avg: 169.59, max: 258)
#
# Run: 424, exploration: 0.01, score: 143
# Scores: (min: 97, avg: 169.86, max: 258)
#
# Run: 425, exploration: 0.01, score: 173
# Scores: (min: 118, avg: 170.62, max: 258)
#
# Run: 426, exploration: 0.01, score: 161
# Scores: (min: 118, avg: 170.95, max: 258)
#
# Run: 427, exploration: 0.01, score: 151
# Scores: (min: 118, avg: 171.01, max: 258)
#
# Run: 428, exploration: 0.01, score: 158
# Scores: (min: 118, avg: 171.01, max: 258)
#
# Run: 429, exploration: 0.01, score: 155
# Scores: (min: 118, avg: 171.24, max: 258)
#
# Run: 430, exploration: 0.01, score: 145
# Scores: (min: 118, avg: 171.43, max: 258)
#
# Run: 431, exploration: 0.01, score: 164
# Scores: (min: 133, avg: 171.89, max: 258)
#
# Run: 432, exploration: 0.01, score: 156
# Scores: (min: 133, avg: 171.64, max: 258)
#
# Run: 433, exploration: 0.01, score: 149
# Scores: (min: 134, avg: 171.8, max: 258)
#
# Run: 434, exploration: 0.01, score: 147
# Scores: (min: 136, avg: 171.93, max: 258)
#
# Run: 435, exploration: 0.01, score: 159
# Scores: (min: 136, avg: 172.13, max: 258)
#
# Run: 436, exploration: 0.01, score: 154
# Scores: (min: 136, avg: 171.98, max: 258)
#
# Run: 437, exploration: 0.01, score: 162
# Scores: (min: 136, avg: 172.15, max: 258)
#
# Run: 438, exploration: 0.01, score: 133
# Scores: (min: 133, avg: 171.92, max: 258)
#
# Run: 439, exploration: 0.01, score: 151
# Scores: (min: 133, avg: 171.92, max: 258)
#
# Run: 440, exploration: 0.01, score: 154
# Scores: (min: 133, avg: 171.45, max: 258)
#
# Run: 441, exploration: 0.01, score: 184
# Scores: (min: 133, avg: 171.28, max: 258)
#
# Run: 442, exploration: 0.01, score: 156
# Scores: (min: 133, avg: 171.07, max: 258)
#
# Run: 443, exploration: 0.01, score: 159
# Scores: (min: 133, avg: 170.44, max: 258)
#
# Run: 444, exploration: 0.01, score: 139
# Scores: (min: 133, avg: 170.1, max: 258)
#
# Run: 445, exploration: 0.01, score: 139
# Scores: (min: 133, avg: 169.49, max: 258)
#
# Run: 446, exploration: 0.01, score: 140
# Scores: (min: 133, avg: 168.57, max: 258)
#
# Run: 447, exploration: 0.01, score: 172
# Scores: (min: 133, avg: 168.37, max: 258)
#
# Run: 448, exploration: 0.01, score: 169
# Scores: (min: 133, avg: 168.23, max: 258)
#
# Run: 449, exploration: 0.01, score: 157
# Scores: (min: 133, avg: 167.95, max: 258)
#
# Run: 450, exploration: 0.01, score: 161
# Scores: (min: 133, avg: 167.4, max: 258)
#
# Run: 451, exploration: 0.01, score: 125
# Scores: (min: 125, avg: 166.59, max: 258)
#
# Run: 452, exploration: 0.01, score: 141
# Scores: (min: 125, avg: 166.18, max: 258)
# C:\ProgramData\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.125833). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# Run: 453, exploration: 0.01, score: 154
# Scores: (min: 125, avg: 165.95, max: 258)
#
# Run: 454, exploration: 0.01, score: 134
# Scores: (min: 125, avg: 164.71, max: 255)
#
# Run: 455, exploration: 0.01, score: 134
# Scores: (min: 125, avg: 164.14, max: 255)
#
# Run: 456, exploration: 0.01, score: 143
# Scores: (min: 125, avg: 163.9, max: 255)
#
# Run: 457, exploration: 0.01, score: 139
# Scores: (min: 125, avg: 163.16, max: 255)
#
# Run: 458, exploration: 0.01, score: 158
# Scores: (min: 125, avg: 162.23, max: 255)
#
# Run: 459, exploration: 0.01, score: 213
# Scores: (min: 125, avg: 162.71, max: 255)
#
# Run: 460, exploration: 0.01, score: 170
# Scores: (min: 125, avg: 162.21, max: 255)
#
# Run: 461, exploration: 0.01, score: 186
# Scores: (min: 125, avg: 161.86, max: 255)
#
# Run: 462, exploration: 0.01, score: 167
# Scores: (min: 125, avg: 160.98, max: 220)
#
# Run: 463, exploration: 0.01, score: 172
# Scores: (min: 125, avg: 160.73, max: 220)
#
# Run: 464, exploration: 0.01, score: 212
# Scores: (min: 125, avg: 160.94, max: 220)
#
# Run: 465, exploration: 0.01, score: 235
# Scores: (min: 125, avg: 161.66, max: 235)
#
# Run: 466, exploration: 0.01, score: 164
# Scores: (min: 125, avg: 161.9, max: 235)
#
# Run: 467, exploration: 0.01, score: 177
# Scores: (min: 125, avg: 161.97, max: 235)
#
# Run: 468, exploration: 0.01, score: 191
# Scores: (min: 125, avg: 161.96, max: 235)
#
# Run: 469, exploration: 0.01, score: 166
# Scores: (min: 125, avg: 161.99, max: 235)
#
# Run: 470, exploration: 0.01, score: 145
# Scores: (min: 125, avg: 161.9, max: 235)
#
# Run: 471, exploration: 0.01, score: 154
# Scores: (min: 125, avg: 161.81, max: 235)
#
# Run: 472, exploration: 0.01, score: 211
# Scores: (min: 125, avg: 161.72, max: 235)
#
# Run: 473, exploration: 0.01, score: 145
# Scores: (min: 125, avg: 161.36, max: 235)
#
# Run: 474, exploration: 0.01, score: 163
# Scores: (min: 125, avg: 161.42, max: 235)
#
# Run: 475, exploration: 0.01, score: 148
# Scores: (min: 125, avg: 161.24, max: 235)
#
# Run: 476, exploration: 0.01, score: 177
# Scores: (min: 125, avg: 161.5, max: 235)
#
# Run: 477, exploration: 0.01, score: 138
# Scores: (min: 125, avg: 161.23, max: 235)
#
# Run: 478, exploration: 0.01, score: 137
# Scores: (min: 125, avg: 160.52, max: 235)
#
# Run: 479, exploration: 0.01, score: 148
# Scores: (min: 125, avg: 160.25, max: 235)
#
# Run: 480, exploration: 0.01, score: 129
# Scores: (min: 125, avg: 159.93, max: 235)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-16-e96181ad5907> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#      89
#
# <ipython-input-16-e96181ad5907> in experience_replay(self)
#      56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
# ---> 58             self.model.fit(state, q_values, verbose=0)
#      59         self.exploration_rate *= EXPLORATION_DECAY
#      60         self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.5  #Changed decay rate
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.01, score: 33
# Scores: (min: 33, avg: 33, max: 33)
#
# Run: 2, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 21.5, max: 33)
#
# Run: 3, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 17.333333333333332, max: 33)
#
# Run: 4, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 15.25, max: 33)
#
# Run: 5, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 14.2, max: 33)
#
# Run: 6, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 13.666666666666666, max: 33)
#
# Run: 7, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 13, max: 33)
#
# Run: 8, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 12.5, max: 33)
#
# Run: 9, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 12.11111111111111, max: 33)
#
# Run: 10, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 11.9, max: 33)
#
# Run: 11, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 11.727272727272727, max: 33)
#
# Run: 12, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 11.666666666666666, max: 33)
#
# Run: 13, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 11.461538461538462, max: 33)
#
# Run: 14, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 11.642857142857142, max: 33)
#
# Run: 15, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 11.8, max: 33)
#
# Run: 16, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 11.875, max: 33)
#
# Run: 17, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 12.117647058823529, max: 33)
#
# Run: 18, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 12.055555555555555, max: 33)
#
# Run: 19, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 12.157894736842104, max: 33)
#
# Run: 20, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 12.25, max: 33)
#
# Run: 21, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 12.19047619047619, max: 33)
#
# Run: 22, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 12.227272727272727, max: 33)
#
# Run: 23, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 12.173913043478262, max: 33)
#
# Run: 24, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 12.083333333333334, max: 33)
#
# Run: 25, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 12.08, max: 33)
#
# Run: 26, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 12.153846153846153, max: 33)
#
# Run: 27, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 12.185185185185185, max: 33)
#
# Run: 28, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 12.071428571428571, max: 33)
#
# Run: 29, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 12.793103448275861, max: 33)
#
# Run: 30, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 13.266666666666667, max: 33)
#
# Run: 31, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.096774193548388, max: 33)
#
# Run: 32, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.96875, max: 33)
#
# Run: 33, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.848484848484848, max: 33)
#
# Run: 34, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.764705882352942, max: 33)
#
# Run: 35, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.657142857142857, max: 33)
#
# Run: 36, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.527777777777779, max: 33)
#
# Run: 37, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.432432432432432, max: 33)
#
# Run: 38, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.368421052631579, max: 33)
#
# Run: 39, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.307692307692308, max: 33)
#
# Run: 40, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.25, max: 33)
#
# Run: 41, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.146341463414634, max: 33)
#
# Run: 42, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.071428571428571, max: 33)
#
# Run: 43, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.023255813953488, max: 33)
#
# Run: 44, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.954545454545455, max: 33)
#
# Run: 45, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.911111111111111, max: 33)
#
# Run: 46, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.869565217391305, max: 33)
#
# Run: 47, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.829787234042554, max: 33)
#
# Run: 48, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.8125, max: 33)
#
# Run: 49, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.775510204081632, max: 33)
#
# Run: 50, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.72, max: 33)
#
# Run: 51, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.745098039215685, max: 33)
#
# Run: 52, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.75, max: 33)
#
# Run: 53, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.716981132075471, max: 33)
#
# Run: 54, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.962962962962964, max: 33)
#
# Run: 55, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.963636363636363, max: 33)
#
# Run: 56, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.964285714285714, max: 33)
#
# Run: 57, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 12.192982456140351, max: 33)
#
# Run: 58, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 12.53448275862069, max: 33)
#
# Run: 59, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.525423728813559, max: 33)
#
# Run: 60, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.516666666666667, max: 33)
#
# Run: 61, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.491803278688524, max: 33)
#
# Run: 62, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 13.064516129032258, max: 48)
#
# Run: 63, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.015873015873016, max: 48)
#
# Run: 64, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 13.765625, max: 61)
#
# Run: 65, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.738461538461538, max: 61)
#
# Run: 66, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.833333333333334, max: 61)
#
# Run: 67, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 15.73134328358209, max: 141)
#
# Run: 68, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 16.323529411764707, max: 141)
#
# Run: 69, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 16.985507246376812, max: 141)
#
# Run: 70, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 18.057142857142857, max: 141)
#
# Run: 71, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 18.746478873239436, max: 141)
#
# Run: 72, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 20.11111111111111, max: 141)
#
# Run: 73, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 20.945205479452056, max: 141)
#
# Run: 74, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 22.39189189189189, max: 141)
#
# Run: 75, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 23.706666666666667, max: 141)
#
# Run: 76, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 25, max: 141)
#
# Run: 77, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 26.61038961038961, max: 149)
#
# Run: 78, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 28.58974358974359, max: 181)
#
# Run: 79, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 29.645569620253166, max: 181)
#
# Run: 80, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 31.1375, max: 181)
#
# Run: 81, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 32.28395061728395, max: 181)
#
# Run: 82, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 34.08536585365854, max: 181)
#
# Run: 83, exploration: 0.01, score: 113
# Scores: (min: 8, avg: 35.036144578313255, max: 181)
#
# Run: 84, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 36.773809523809526, max: 181)
#
# Run: 85, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 38.64705882352941, max: 196)
#
# Run: 86, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 40.593023255813954, max: 206)
#
# Run: 87, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 42.52873563218391, max: 209)
#
# Run: 88, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 44.125, max: 209)
#
# Run: 89, exploration: 0.01, score: 293
# Scores: (min: 8, avg: 46.92134831460674, max: 293)
#
# Run: 90, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 48.955555555555556, max: 293)
#
# Run: 91, exploration: 0.01, score: 211
# Scores: (min: 8, avg: 50.73626373626374, max: 293)
#
# Run: 92, exploration: 0.01, score: 290
# Scores: (min: 8, avg: 53.33695652173913, max: 293)
#
# Run: 93, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 55.494623655913976, max: 293)
#
# Run: 94, exploration: 0.01, score: 264
# Scores: (min: 8, avg: 57.712765957446805, max: 293)
#
# Run: 95, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 59.189473684210526, max: 293)
#
# Run: 96, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 60.03125, max: 293)
#
# Run: 97, exploration: 0.01, score: 228
# Scores: (min: 8, avg: 61.76288659793814, max: 293)
#
# Run: 98, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 63.53061224489796, max: 293)
#
# Run: 99, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 63.95959595959596, max: 293)
#
# Run: 100, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 64.3, max: 293)
#
# Run: 101, exploration: 0.01, score: 261
# Scores: (min: 8, avg: 66.58, max: 293)
#
# Run: 102, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 68.07, max: 293)
#
# Run: 103, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 69.88, max: 293)
#
# Run: 104, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 72.3, max: 293)
#
# Run: 105, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 73.86, max: 293)
#
# Run: 106, exploration: 0.01, score: 213
# Scores: (min: 8, avg: 75.88, max: 293)
#
# Run: 107, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 78.02, max: 293)
#
# Run: 108, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 79.67, max: 293)
#
# Run: 109, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 80.79, max: 293)
#
# Run: 110, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 82.42, max: 293)
#
# Run: 111, exploration: 0.01, score: 262
# Scores: (min: 8, avg: 84.94, max: 293)
#
# Run: 112, exploration: 0.01, score: 246
# Scores: (min: 8, avg: 87.29, max: 293)
#
# Run: 113, exploration: 0.01, score: 283
# Scores: (min: 8, avg: 90.03, max: 293)
#
# Run: 114, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 91.63, max: 293)
#
# Run: 115, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 92.63, max: 293)
#
# Run: 116, exploration: 0.01, score: 302
# Scores: (min: 8, avg: 95.52, max: 302)
#
# Run: 117, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 97.77, max: 302)
#
# Run: 118, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 99.36, max: 302)
#
# Run: 119, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 101.45, max: 302)
#
# Run: 120, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 103.46, max: 302)
#
# Run: 121, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 105.41, max: 302)
#
# Run: 122, exploration: 0.01, score: 425
# Scores: (min: 8, avg: 109.53, max: 425)
#
# Run: 123, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 111.28, max: 425)
#
# Run: 124, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 113.07, max: 425)
#
# Run: 125, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 114.63, max: 425)
#
# Run: 126, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 116.87, max: 425)
#
# Run: 127, exploration: 0.01, score: 342
# Scores: (min: 8, avg: 120.16, max: 425)
#
# Run: 128, exploration: 0.01, score: 263
# Scores: (min: 8, avg: 122.7, max: 425)
#
# Run: 129, exploration: 0.01, score: 277
# Scores: (min: 8, avg: 125.14, max: 425)
#
# Run: 130, exploration: 0.01, score: 317
# Scores: (min: 8, avg: 128.04, max: 425)
#
# Run: 131, exploration: 0.01, score: 346
# Scores: (min: 8, avg: 131.42, max: 425)
#
# Run: 132, exploration: 0.01, score: 240
# Scores: (min: 8, avg: 133.73, max: 425)
#
# Run: 133, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 135.03, max: 425)
#
# Run: 134, exploration: 0.01, score: 265
# Scores: (min: 8, avg: 137.58, max: 425)
#
# Run: 135, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 139.59, max: 425)
#
# Run: 136, exploration: 0.01, score: 257
# Scores: (min: 8, avg: 142.08, max: 425)
#
# Run: 137, exploration: 0.01, score: 446
# Scores: (min: 8, avg: 146.45, max: 446)
#
# Run: 138, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 148.32, max: 446)
#
# Run: 139, exploration: 0.01, score: 319
# Scores: (min: 8, avg: 151.41, max: 446)
#
# Run: 140, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 153.47, max: 446)
#
# Run: 141, exploration: 0.01, score: 197
# Scores: (min: 9, avg: 155.36, max: 446)
#
# Run: 142, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 157.33, max: 446)
#
# Run: 143, exploration: 0.01, score: 344
# Scores: (min: 9, avg: 160.67, max: 446)
#
# Run: 144, exploration: 0.01, score: 252
# Scores: (min: 9, avg: 163.1, max: 446)
#
# Run: 145, exploration: 0.01, score: 319
# Scores: (min: 9, avg: 166.19, max: 446)
#
# Run: 146, exploration: 0.01, score: 266
# Scores: (min: 9, avg: 168.75, max: 446)
#
# Run: 147, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 171.08, max: 446)
#
# Run: 148, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 172.9, max: 446)
#
# Run: 149, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 174.8, max: 446)
#
# Run: 150, exploration: 0.01, score: 286
# Scores: (min: 10, avg: 177.57, max: 446)
#
# Run: 151, exploration: 0.01, score: 344
# Scores: (min: 10, avg: 180.88, max: 446)
#
# Run: 152, exploration: 0.01, score: 434
# Scores: (min: 10, avg: 185.1, max: 446)
#
# Run: 153, exploration: 0.01, score: 248
# Scores: (min: 10, avg: 187.48, max: 446)
#
# Run: 154, exploration: 0.01, score: 255
# Scores: (min: 10, avg: 189.78, max: 446)
#
# Run: 155, exploration: 0.01, score: 345
# Scores: (min: 10, avg: 193.11, max: 446)
#
# Run: 156, exploration: 0.01, score: 275
# Scores: (min: 10, avg: 195.74, max: 446)
#
# Solved in 56 runs, 156 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-19-c4e897ab6367> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 2.0  #Increased the max exploration
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 2.0, score: 14
# Scores: (min: 14, avg: 14, max: 14)
#
# Run: 2, exploration: 1.8738293857596078, score: 19
# Scores: (min: 14, avg: 16.5, max: 19)
#
# Run: 3, exploration: 1.6122131818527914, score: 31
# Scores: (min: 14, avg: 21.333333333333332, max: 31)
#
# Run: 4, exploration: 1.39409320167099, score: 30
# Scores: (min: 14, avg: 23.5, max: 31)
#
# Run: 5, exploration: 1.306146403889398, score: 14
# Scores: (min: 14, avg: 21.6, max: 31)
#
# Run: 6, exploration: 1.1994557527734657, score: 18
# Scores: (min: 14, avg: 21, max: 31)
#
# Run: 7, exploration: 1.095972570980084, score: 19
# Scores: (min: 14, avg: 20.714285714285715, max: 31)
#
# Run: 8, exploration: 1.0423906149717752, score: 11
# Scores: (min: 11, avg: 19.5, max: 31)
#
# Run: 9, exploration: 0.9717479274726352, score: 15
# Scores: (min: 11, avg: 19, max: 31)
#
# Run: 10, exploration: 0.8277366916839737, score: 33
# Scores: (min: 11, avg: 20.4, max: 33)
#
# Run: 11, exploration: 0.771641074933063, score: 15
# Scores: (min: 11, avg: 19.90909090909091, max: 33)
#
# Run: 12, exploration: 0.7050676532358481, score: 19
# Scores: (min: 11, avg: 19.833333333333332, max: 33)
#
# Run: 13, exploration: 0.5975750484794964, score: 34
# Scores: (min: 11, avg: 20.923076923076923, max: 34)
#
# Run: 14, exploration: 0.5683596823224237, score: 11
# Scores: (min: 11, avg: 20.214285714285715, max: 34)
#
# Run: 15, exploration: 0.5432890970906181, score: 10
# Scores: (min: 10, avg: 19.533333333333335, max: 34)
#
# Run: 16, exploration: 0.5090155375456025, score: 14
# Scores: (min: 10, avg: 19.1875, max: 34)
#
# Run: 17, exploration: 0.4769041360305864, score: 14
# Scores: (min: 10, avg: 18.88235294117647, max: 34)
#
# Run: 18, exploration: 0.44014967029467117, score: 17
# Scores: (min: 10, avg: 18.77777777777778, max: 34)
#
# Run: 19, exploration: 0.41445496800530524, score: 13
# Scores: (min: 10, avg: 18.473684210526315, max: 34)
#
# Run: 20, exploration: 0.39617318461478707, score: 10
# Scores: (min: 10, avg: 18.05, max: 34)
#
# Run: 21, exploration: 0.37680432930601043, score: 11
# Scores: (min: 10, avg: 17.714285714285715, max: 34)
#
# Run: 22, exploration: 0.36199329795339236, score: 9
# Scores: (min: 9, avg: 17.318181818181817, max: 34)
#
# Run: 23, exploration: 0.34086114530306516, score: 13
# Scores: (min: 9, avg: 17.130434782608695, max: 34)
#
# Run: 24, exploration: 0.32096262840832107, score: 13
# Scores: (min: 9, avg: 16.958333333333332, max: 34)
#
# Run: 25, exploration: 0.3052708073800754, score: 11
# Scores: (min: 9, avg: 16.72, max: 34)
#
# Run: 26, exploration: 0.2860127047416731, score: 14
# Scores: (min: 9, avg: 16.615384615384617, max: 34)
#
# Run: 27, exploration: 0.2706694330171124, score: 12
# Scores: (min: 9, avg: 16.444444444444443, max: 34)
#
# Run: 28, exploration: 0.26003024140804754, score: 9
# Scores: (min: 9, avg: 16.178571428571427, max: 34)
#
# Run: 29, exploration: 0.24731739683065423, score: 11
# Scores: (min: 9, avg: 16, max: 34)
#
# Run: 30, exploration: 0.2375961026903953, score: 9
# Scores: (min: 9, avg: 15.766666666666667, max: 34)
#
# Run: 31, exploration: 0.2271156384201214, score: 10
# Scores: (min: 9, avg: 15.580645161290322, max: 34)
#
# Run: 32, exploration: 0.2170974718478178, score: 10
# Scores: (min: 9, avg: 15.40625, max: 34)
#
# Run: 33, exploration: 0.20545118674910237, score: 12
# Scores: (min: 9, avg: 15.303030303030303, max: 34)
#
# Run: 34, exploration: 0.1963886482746597, score: 10
# Scores: (min: 9, avg: 15.147058823529411, max: 34)
#
# Run: 35, exploration: 0.18772586219347556, score: 10
# Scores: (min: 9, avg: 15, max: 34)
#
# Run: 36, exploration: 0.1776552294362228, score: 12
# Scores: (min: 9, avg: 14.916666666666666, max: 34)
#
# Run: 37, exploration: 0.17067214307417744, score: 9
# Scores: (min: 9, avg: 14.756756756756756, max: 34)
#
# Run: 38, exploration: 0.1623280042661538, score: 11
# Scores: (min: 9, avg: 14.657894736842104, max: 34)
#
# Run: 39, exploration: 0.15361985026925074, score: 12
# Scores: (min: 9, avg: 14.58974358974359, max: 34)
#
# Run: 40, exploration: 0.13966444877566, score: 20
# Scores: (min: 9, avg: 14.725, max: 34)
#
# Run: 41, exploration: 0.1335037910517066, score: 10
# Scores: (min: 9, avg: 14.609756097560975, max: 34)
#
# Run: 42, exploration: 0.12697680812486375, score: 11
# Scores: (min: 9, avg: 14.523809523809524, max: 34)
#
# Run: 43, exploration: 0.12076892854176642, score: 11
# Scores: (min: 9, avg: 14.44186046511628, max: 34)
#
# Run: 44, exploration: 0.11429022862466306, score: 12
# Scores: (min: 9, avg: 14.386363636363637, max: 34)
#
# Run: 45, exploration: 0.1087025942581662, score: 11
# Scores: (min: 9, avg: 14.311111111111112, max: 34)
#
# Run: 46, exploration: 0.10495459911801355, score: 8
# Scores: (min: 8, avg: 14.173913043478262, max: 34)
#
# Run: 47, exploration: 0.09735262927663683, score: 16
# Scores: (min: 8, avg: 14.212765957446809, max: 34)
#
# Run: 48, exploration: 0.09166945603996143, score: 13
# Scores: (min: 8, avg: 14.1875, max: 34)
#
# Run: 49, exploration: 0.08418157112658312, score: 18
# Scores: (min: 8, avg: 14.26530612244898, max: 34)
#
# Run: 50, exploration: 0.07847659610391099, score: 15
# Scores: (min: 8, avg: 14.28, max: 34)
#
# Run: 51, exploration: 0.07463988555890047, score: 11
# Scores: (min: 8, avg: 14.215686274509803, max: 34)
#
# Run: 52, exploration: 0.06888747347218435, score: 17
# Scores: (min: 8, avg: 14.26923076923077, max: 34)
#
# Run: 53, exploration: 0.06617971655421497, score: 9
# Scores: (min: 8, avg: 14.169811320754716, max: 34)
#
# Run: 54, exploration: 0.06077392358275956, score: 18
# Scores: (min: 8, avg: 14.24074074074074, max: 34)
#
# Run: 55, exploration: 0.05442833533657429, score: 23
# Scores: (min: 8, avg: 14.4, max: 34)
#
# Run: 56, exploration: 0.049982436684689976, score: 18
# Scores: (min: 8, avg: 14.464285714285714, max: 34)
#
# Run: 57, exploration: 0.04498856287435989, score: 22
# Scores: (min: 8, avg: 14.596491228070175, max: 34)
#
# Run: 58, exploration: 0.040493639841296336, score: 22
# Scores: (min: 8, avg: 14.724137931034482, max: 34)
#
# Run: 59, exploration: 0.0350151634095864, score: 30
# Scores: (min: 8, avg: 14.983050847457626, max: 34)
#
# Run: 60, exploration: 0.03199422619513667, score: 19
# Scores: (min: 8, avg: 15.05, max: 34)
#
# Run: 61, exploration: 0.029676851399963254, score: 16
# Scores: (min: 8, avg: 15.065573770491802, max: 34)
#
# Run: 62, exploration: 0.026845990797959216, score: 21
# Scores: (min: 8, avg: 15.161290322580646, max: 34)
#
# Run: 63, exploration: 0.024653115459055686, score: 18
# Scores: (min: 8, avg: 15.206349206349206, max: 34)
#
# Run: 64, exploration: 0.022982376768357245, score: 15
# Scores: (min: 8, avg: 15.203125, max: 34)
#
# Run: 65, exploration: 0.020377405041327654, score: 25
# Scores: (min: 8, avg: 15.353846153846154, max: 34)
#
# Run: 66, exploration: 0.019091890185982868, score: 14
# Scores: (min: 8, avg: 15.333333333333334, max: 34)
#
# Run: 67, exploration: 0.01762049966814186, score: 17
# Scores: (min: 8, avg: 15.35820895522388, max: 34)
#
# Run: 68, exploration: 0.015939688667476547, score: 21
# Scores: (min: 8, avg: 15.441176470588236, max: 34)
#
# Run: 69, exploration: 0.014062316008749408, score: 26
# Scores: (min: 8, avg: 15.594202898550725, max: 34)
#
# Run: 70, exploration: 0.011978306926540472, score: 33
# Scores: (min: 8, avg: 15.842857142857143, max: 34)
#
# Run: 71, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 16.225352112676056, max: 43)
#
# Run: 72, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 16.458333333333332, max: 43)
#
# Run: 73, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 16.63013698630137, max: 43)
#
# Run: 74, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 16.824324324324323, max: 43)
#
# Run: 75, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 17.093333333333334, max: 43)
#
# Run: 76, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 17.32894736842105, max: 43)
#
# Run: 77, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 17.766233766233768, max: 51)
#
# Run: 78, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 17.884615384615383, max: 51)
#
# Run: 79, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 18.050632911392405, max: 51)
#
# Run: 80, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 18.475, max: 52)
#
# Run: 81, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 18.82716049382716, max: 52)
#
# Run: 82, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 18.9390243902439, max: 52)
#
# Run: 83, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 19.710843373493976, max: 83)
#
# Run: 84, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 20.13095238095238, max: 83)
#
# Run: 85, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 20.458823529411763, max: 83)
#
# Run: 86, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 20.593023255813954, max: 83)
#
# Run: 87, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 21.06896551724138, max: 83)
#
# Run: 88, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 21.363636363636363, max: 83)
#
# Run: 89, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 21.39325842696629, max: 83)
#
# Run: 90, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 21.566666666666666, max: 83)
#
# Run: 91, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 21.604395604395606, max: 83)
#
# Run: 92, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 21.619565217391305, max: 83)
#
# Run: 93, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 21.602150537634408, max: 83)
#
# Run: 94, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 21.69148936170213, max: 83)
#
# Run: 95, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 21.88421052631579, max: 83)
#
# Run: 96, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 22, max: 83)
#
# Run: 97, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 22.030927835051546, max: 83)
#
# Run: 98, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 22.122448979591837, max: 83)
#
# Run: 99, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 22.727272727272727, max: 83)
#
# Run: 100, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 22.84, max: 83)
#
# Run: 101, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 23.06, max: 83)
#
# Run: 102, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 23.28, max: 83)
#
# Run: 103, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 23.31, max: 83)
#
# Run: 104, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 24.18, max: 117)
#
# Run: 105, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 25.04, max: 117)
#
# Run: 106, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 25.66, max: 117)
#
# Run: 107, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 26.59, max: 117)
#
# Run: 108, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 27, max: 117)
#
# Run: 109, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 28.21, max: 136)
#
# Run: 110, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 28.72, max: 136)
#
# Run: 111, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 29.51, max: 136)
#
# Run: 112, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 30.96, max: 164)
#
# Run: 113, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 31.38, max: 164)
#
# Run: 114, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 32.03, max: 164)
#
# Run: 115, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 32.85, max: 164)
#
# Run: 116, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 33.62, max: 164)
#
# Run: 117, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 34.73, max: 164)
#
# Run: 118, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 35.64, max: 164)
#
# Run: 119, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 36.19, max: 164)
#
# Run: 120, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 36.76, max: 164)
#
# Run: 121, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 37.5, max: 164)
#
# Run: 122, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 38.49, max: 164)
#
# Run: 123, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 40.4, max: 204)
#
# Run: 124, exploration: 0.01, score: 226
# Scores: (min: 8, avg: 42.53, max: 226)
#
# Run: 125, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 44.37, max: 226)
#
# Run: 126, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 45.85, max: 226)
#
# Run: 127, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 47.17, max: 226)
#
# Run: 128, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 48.53, max: 226)
#
# Run: 129, exploration: 0.01, score: 244
# Scores: (min: 8, avg: 50.86, max: 244)
#
# Run: 130, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 52.56, max: 244)
#
# Run: 131, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 53.99, max: 244)
#
# Run: 132, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 55.87, max: 244)
#
# Run: 133, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 57.48, max: 244)
#
# Run: 134, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 59.21, max: 244)
#
# Run: 135, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 60.83, max: 244)
#
# Run: 136, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 62.42, max: 244)
#
# Run: 137, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 64.33, max: 244)
#
# Run: 138, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 65.65, max: 244)
#
# Run: 139, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 67.86, max: 244)
#
# Run: 140, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 69.6, max: 244)
#
# Run: 141, exploration: 0.01, score: 244
# Scores: (min: 8, avg: 71.94, max: 244)
#
# Run: 142, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 73.88, max: 244)
#
# Run: 143, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 75.5, max: 244)
#
# Run: 144, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 77.07, max: 244)
#
# Run: 145, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 78.96, max: 244)
#
# Run: 146, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 80.39, max: 244)
#
# Run: 147, exploration: 0.01, score: 238
# Scores: (min: 9, avg: 82.61, max: 244)
#
# Run: 148, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 84.46, max: 244)
#
# Run: 149, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 86.35, max: 244)
#
# Run: 150, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 88.32, max: 244)
#
# Run: 151, exploration: 0.01, score: 277
# Scores: (min: 9, avg: 90.98, max: 277)
#
# Run: 152, exploration: 0.01, score: 235
# Scores: (min: 9, avg: 93.16, max: 277)
#
# Run: 153, exploration: 0.01, score: 162
# Scores: (min: 14, avg: 94.69, max: 277)
#
# Run: 154, exploration: 0.01, score: 130
# Scores: (min: 14, avg: 95.81, max: 277)
#
# Run: 155, exploration: 0.01, score: 194
# Scores: (min: 14, avg: 97.52, max: 277)
#
# Run: 156, exploration: 0.01, score: 200
# Scores: (min: 14, avg: 99.34, max: 277)
#
# Run: 157, exploration: 0.01, score: 181
# Scores: (min: 14, avg: 100.93, max: 277)
#
# Run: 158, exploration: 0.01, score: 150
# Scores: (min: 14, avg: 102.21, max: 277)
#
# Run: 159, exploration: 0.01, score: 200
# Scores: (min: 14, avg: 103.91, max: 277)
#
# Run: 160, exploration: 0.01, score: 150
# Scores: (min: 14, avg: 105.22, max: 277)
#
# Run: 161, exploration: 0.01, score: 175
# Scores: (min: 14, avg: 106.81, max: 277)
#
# Run: 162, exploration: 0.01, score: 297
# Scores: (min: 14, avg: 109.57, max: 297)
#
# Run: 163, exploration: 0.01, score: 135
# Scores: (min: 14, avg: 110.74, max: 297)
#
# Run: 164, exploration: 0.01, score: 193
# Scores: (min: 14, avg: 112.52, max: 297)
#
# Run: 165, exploration: 0.01, score: 278
# Scores: (min: 14, avg: 115.05, max: 297)
#
# Run: 166, exploration: 0.01, score: 189
# Scores: (min: 17, avg: 116.8, max: 297)
#
# Run: 167, exploration: 0.01, score: 198
# Scores: (min: 20, avg: 118.61, max: 297)
#
# Run: 168, exploration: 0.01, score: 182
# Scores: (min: 20, avg: 120.22, max: 297)
#
# Run: 169, exploration: 0.01, score: 142
# Scores: (min: 20, avg: 121.38, max: 297)
#
# Run: 170, exploration: 0.01, score: 245
# Scores: (min: 20, avg: 123.5, max: 297)
#
# Run: 171, exploration: 0.01, score: 210
# Scores: (min: 20, avg: 125.17, max: 297)
#
# Run: 172, exploration: 0.01, score: 114
# Scores: (min: 20, avg: 125.98, max: 297)
#
# Run: 173, exploration: 0.01, score: 186
# Scores: (min: 20, avg: 127.55, max: 297)
#
# Run: 174, exploration: 0.01, score: 148
# Scores: (min: 20, avg: 128.72, max: 297)
#
# Run: 175, exploration: 0.01, score: 132
# Scores: (min: 20, avg: 129.67, max: 297)
#
# Run: 176, exploration: 0.01, score: 204
# Scores: (min: 20, avg: 131.36, max: 297)
#
# Run: 177, exploration: 0.01, score: 279
# Scores: (min: 20, avg: 133.64, max: 297)
#
# Run: 178, exploration: 0.01, score: 155
# Scores: (min: 20, avg: 134.92, max: 297)
#
# Run: 179, exploration: 0.01, score: 173
# Scores: (min: 20, avg: 136.34, max: 297)
#
# Run: 180, exploration: 0.01, score: 245
# Scores: (min: 20, avg: 138.27, max: 297)
#
# Run: 181, exploration: 0.01, score: 303
# Scores: (min: 20, avg: 140.83, max: 303)
#
# Run: 182, exploration: 0.01, score: 146
# Scores: (min: 20, avg: 142.01, max: 303)
#
# Run: 183, exploration: 0.01, score: 129
# Scores: (min: 20, avg: 142.47, max: 303)
#
# Run: 184, exploration: 0.01, score: 141
# Scores: (min: 20, avg: 143.33, max: 303)
#
# Run: 185, exploration: 0.01, score: 209
# Scores: (min: 20, avg: 144.94, max: 303)
#
# Run: 186, exploration: 0.01, score: 196
# Scores: (min: 20, avg: 146.58, max: 303)
#
# Run: 187, exploration: 0.01, score: 132
# Scores: (min: 20, avg: 147.28, max: 303)
#
# Run: 188, exploration: 0.01, score: 131
# Scores: (min: 20, avg: 148.12, max: 303)
#
# Run: 189, exploration: 0.01, score: 304
# Scores: (min: 20, avg: 150.92, max: 304)
#
# Run: 190, exploration: 0.01, score: 163
# Scores: (min: 20, avg: 152.18, max: 304)
#
# Run: 191, exploration: 0.01, score: 159
# Scores: (min: 20, avg: 153.52, max: 304)
#
# Run: 192, exploration: 0.01, score: 178
# Scores: (min: 20, avg: 155.07, max: 304)
#
# Run: 193, exploration: 0.01, score: 219
# Scores: (min: 25, avg: 157.06, max: 304)
#
# Run: 194, exploration: 0.01, score: 125
# Scores: (min: 25, avg: 158.01, max: 304)
#
# Run: 195, exploration: 0.01, score: 256
# Scores: (min: 25, avg: 160.17, max: 304)
#
# Run: 196, exploration: 0.01, score: 201
# Scores: (min: 25, avg: 161.85, max: 304)
#
# Run: 197, exploration: 0.01, score: 242
# Scores: (min: 31, avg: 164.02, max: 304)
#
# Run: 198, exploration: 0.01, score: 235
# Scores: (min: 34, avg: 166.06, max: 304)
#
# Run: 199, exploration: 0.01, score: 152
# Scores: (min: 34, avg: 166.76, max: 304)
#
# Run: 200, exploration: 0.01, score: 179
# Scores: (min: 34, avg: 168.21, max: 304)
#
# Run: 201, exploration: 0.01, score: 178
# Scores: (min: 34, avg: 169.63, max: 304)
#
# Run: 202, exploration: 0.01, score: 137
# Scores: (min: 34, avg: 170.59, max: 304)
#
# Run: 203, exploration: 0.01, score: 177
# Scores: (min: 52, avg: 172.02, max: 304)
#
# Run: 204, exploration: 0.01, score: 234
# Scores: (min: 52, avg: 173.19, max: 304)
#
# Run: 205, exploration: 0.01, score: 184
# Scores: (min: 52, avg: 174.03, max: 304)
#
# Run: 206, exploration: 0.01, score: 150
# Scores: (min: 52, avg: 174.73, max: 304)
#
# Run: 207, exploration: 0.01, score: 128
# Scores: (min: 52, avg: 174.89, max: 304)
#
# Run: 208, exploration: 0.01, score: 172
# Scores: (min: 67, avg: 176.09, max: 304)
#
# Run: 209, exploration: 0.01, score: 194
# Scores: (min: 67, avg: 176.67, max: 304)
#
# Run: 210, exploration: 0.01, score: 206
# Scores: (min: 67, avg: 177.89, max: 304)
#
# Run: 211, exploration: 0.01, score: 164
# Scores: (min: 67, avg: 178.59, max: 304)
#
# Run: 212, exploration: 0.01, score: 107
# Scores: (min: 67, avg: 178.02, max: 304)
#
# Run: 213, exploration: 0.01, score: 208
# Scores: (min: 67, avg: 179.34, max: 304)
#
# Run: 214, exploration: 0.01, score: 178
# Scores: (min: 67, avg: 180.36, max: 304)
#
# Run: 215, exploration: 0.01, score: 174
# Scores: (min: 67, avg: 181.18, max: 304)
#
# Run: 216, exploration: 0.01, score: 265
# Scores: (min: 67, avg: 182.92, max: 304)
#
# Run: 217, exploration: 0.01, score: 146
# Scores: (min: 67, avg: 183.13, max: 304)
#
# Run: 218, exploration: 0.01, score: 290
# Scores: (min: 67, avg: 184.95, max: 304)
#
# Run: 219, exploration: 0.01, score: 133
# Scores: (min: 67, avg: 185.6, max: 304)
#
# Run: 220, exploration: 0.01, score: 481
# Scores: (min: 85, avg: 189.74, max: 481)
#
# Run: 221, exploration: 0.01, score: 217
# Scores: (min: 107, avg: 191.06, max: 481)
#
# Run: 222, exploration: 0.01, score: 290
# Scores: (min: 107, avg: 192.88, max: 481)
#
# Run: 223, exploration: 0.01, score: 294
# Scores: (min: 107, avg: 193.78, max: 481)
#
# Run: 224, exploration: 0.01, score: 197
# Scores: (min: 107, avg: 193.49, max: 481)
#
# Run: 225, exploration: 0.01, score: 169
# Scores: (min: 107, avg: 193.23, max: 481)
#
# Run: 226, exploration: 0.01, score: 233
# Scores: (min: 107, avg: 193.94, max: 481)
#
# Run: 227, exploration: 0.01, score: 151
# Scores: (min: 107, avg: 194.01, max: 481)
#
# Run: 228, exploration: 0.01, score: 300
# Scores: (min: 107, avg: 195.56, max: 481)
#
# Solved in 128 runs, 228 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-21-36c7db8cecd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# In this RL =, the agent is attempting to balance the inverted pendulum and is represented by the solver(DQNSolver). The possible state values describe the position, pole angle, velocity, and it's tip velocity. What the cart can do to change the position of the pole isdescribed by the actions(move left, move right).
# DQN (Deep Q-Learning) is used as its reinforcment algorithm and uses the DQNSolver. The algorithm uses expierence replay, this allows the agent to remember the states experienced, then have those expierneces sampled. The algorithm uses those samples to "reduce correlation between subsequebt actions".
# The algorithm uses a discount factor that is not myopic, 0.95. The importance of future rewards is detwermined by the discount factor. A 0 factor will cause the agent to be short sighrted and only consider current rewards. A 1 factor will make it strive for the long term higher rewards.
# In long running training sessions the Q-table has the potential to become to lengthy and not able to fit into the memory, or just be unsearchable do toit's size. The use of a neural network may be substituted fot this table to approximate the response with Q-values computed usimng the Bellman equation.
# Usuing the default values of rate, alpha, (0.001) the algorithm Solved in 36 runs, 136 total runs. At 0.01, the run was terminated after 1399 runs while at 0.0001it was terminated after 480 runs. The learning rate is the 'step size'. If a step size is too large, the simulation can hang up and never get to converging at the minimum. That was the case with the 0.01 learning rate. Having a larger step size can be usefull in the begining, however it does tend to become detrimental in the later stages. An option is to adjust the decay rate, this would allow for a higher learing rate early on, while being less as the simulation progresses.
